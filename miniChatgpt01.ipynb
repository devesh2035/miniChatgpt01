# %%
docs = """

Question 1: What is an operating system?
Answer: An operating system (OS) is a software that acts as an interface between computer hardware and the user. It manages hardware resources, provides basic functionality to execute programs, and ensures smooth execution of multiple applications.

Question 2: What are the primary functions of an operating system?
Answer: The primary functions of an operating system include:
Process Management: Scheduling and managing processes.
Memory Management: Allocating and deallocating memory.
File System Management: Handling file operations and storage.
Device Management: Managing input/output devices.
Security and Access Control: Protecting data and resources.
User Interface: Providing a user-friendly interface.

Question 3: What is the difference between a process and a thread?
Answer:
Process: A process is an independent program in execution with its own memory space. It is managed by the operating system.
Thread: A thread is the smallest unit of a process. Multiple threads of a process share the same memory and resources.

Question 4: Explain virtual memory.
Answer: Virtual memory is a memory management technique that gives an application the illusion of having a large contiguous block of memory, even if the physical memory is limited. It uses disk space as an extension of RAM, allowing systems to run larger applications or multiple applications simultaneously.

Question 5: What is the purpose of a kernel in an operating system?
Answer: The kernel is the core part of the operating system responsible for managing system resources, such as CPU, memory, and devices. It facilitates communication between hardware and software and ensures system stability and performance.

Question 6: What are the different types of operating systems?
Answer:
Batch Operating Systems: Processes batches of jobs without user interaction.
Time-Sharing Operating Systems: Allows multiple users to interact simultaneously.
Distributed Operating Systems: Manages a group of distinct computers to appear as a single system.
Real-Time Operating Systems (RTOS): Designed for systems requiring precise timing and reliability.
Mobile Operating Systems: Designed for smartphones and tablets (e.g., Android, iOS).

Question 7: How does multitasking work in an operating system?
Answer: Multitasking allows multiple processes to run concurrently by switching between them rapidly. The operating system uses a scheduler to allocate CPU time slices to each process, creating the illusion of simultaneous execution.

Question 8: What is deadlock in operating systems?
Answer: A deadlock is a situation where a set of processes are unable to proceed because each process is waiting for a resource held by another process. This results in a standstill.

Question 9: Describe the process lifecycle in an operating system.
Answer: The process lifecycle includes:
New: The process is being created.
Ready: The process is waiting to be executed by the CPU.
Running: The process is currently being executed.
Waiting: The process is waiting for an event or resource.
Terminated: The process has completed execution.

Question 10: What is the difference between paging and segmentation?
Answer:
Paging: Memory is divided into fixed-size blocks called pages. It simplifies memory management but may cause fragmentation.
Segmentation: Memory is divided into variable-sized segments based on logical divisions like functions or objects, making it more user-friendly.

Question 11: What is a file system, and why is it important?
Answer: A file system is a method used by operating systems to organize and store files on storage devices. It provides mechanisms for data access, storage, retrieval, and management. Common file systems include NTFS, FAT32, ext4, etc.

Question 12: What are system calls in an operating system?
Answer: System calls are programming interfaces that allow user applications to request services from the kernel. Examples include file operations, process control, and communication.

Question 13: Explain the concept of context switching.
Answer: Context switching is the process of saving the state of a currently running process and loading the state of another process. It allows multitasking and efficient CPU utilization.

Question 14: What is a shell in an operating system?
Answer: A shell is a user interface that allows users to interact with the operating system by executing commands. Examples include bash (Linux) and Command Prompt (Windows).

Question 15: How do modern operating systems ensure security?
Answer: Modern operating systems ensure security through:
Authentication and access control.
Data encryption.
Firewalls and intrusion detection systems.
Sandboxing of applications.
Regular updates and patches.

Question 16: What is the role of an interrupt in operating systems?
Answer: An interrupt is a signal that informs the CPU to stop its current task and execute a high-priority task. Interrupts ensure quick responses to critical events.

Question 17: What is the difference between symmetric and asymmetric multiprocessing?
Answer:
Symmetric Multiprocessing (SMP): All processors share the same memory and tasks equally.
Asymmetric Multiprocessing (AMP): Processors are assigned specific tasks, with one processor typically acting as the master.

Question 18: Explain the concept of a hypervisor.
Answer: A hypervisor is software that creates and manages virtual machines by abstracting hardware resources. Types include:
Type 1: Runs directly on hardware (e.g., VMware ESXi).
Type 2: Runs on a host operating system (e.g., VirtualBox).

Question 19: What are some advanced features of modern operating systems?
Answer:
Support for multicore processing.
Virtualization.
Advanced memory management.
Cloud integration.
High-performance file systems.

Question 20: What are distributed operating systems?
Answer: Distributed operating systems manage multiple interconnected systems to provide a cohesive environment. They enable resource sharing, load balancing, and fault tolerance across nodes."""

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts([docs])

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'a': 2,
#  'and': 3,
#  'is': 4,
#  'operating': 5,
#  'of': 6,
#  'system': 7,
#  'question': 8,
#  'answer': 9,
#  'process': 10,
#  'systems': 11,
#  'an': 12,
#  'to': 13,
#  'memory': 14,
#  'what': 15,
#  'it': 16,
#  'in': 17,
#  'are': 18,
#  'management': 19,
#  'user': 20,
#  'file': 21,
#  'by': 22,
#  'for': 23,
#  'that': 24,
#  'between': 25,
#  'multiple': 26,
#  'as': 27,
#  'hardware': 28,
#  'resources': 29,
#  'applications': 30,
#  'include': 31,
#  'cpu': 32,
#  'interface': 33,
#  'execution': 34,
#  'processes': 35,
#  'allows': 36,
#  'waiting': 37,
#  'on': 38,
#  'software': 39,
#  'manages': 40,
#  'functions': 41,
#  'managing': 42,
#  'storage': 43,
#  'devices': 44,
#  'security': 45,
#  'access': 46,
#  'control': 47,
#  'data': 48,
#  'difference': 49,
#  'thread': 50,
#  'with': 51,
#  'explain': 52,
#  'virtual': 53,
#  'or': 54,
#  'kernel': 55,
#  'time': 56,
#  'distributed': 57,
#  'e': 58,
#  'g': 59,
#  'multitasking': 60,
#  'switching': 61,
#  'resource': 62,
#  'modern': 63,
#  'ensure': 64,
#  'multiprocessing': 65,
#  '1': 66,
#  'provides': 67,
#  'execute': 68,
#  'ensures': 69,
#  '2': 70,
#  'primary': 71,
#  'operations': 72,
#  'friendly': 73,
#  'its': 74,
#  'space': 75,
#  'share': 76,
#  'same': 77,
#  'illusion': 78,
#  'uses': 79,
#  'run': 80,
#  'simultaneously': 81,
#  'communication': 82,
#  'performance': 83,
#  'types': 84,
#  'sharing': 85,
#  'users': 86,
#  'interact': 87,
#  'designed': 88,
#  'how': 89,
#  'each': 90,
#  'deadlock': 91,
#  'another': 92,
#  'lifecycle': 93,
#  'being': 94,
#  'executed': 95,
#  'running': 96,
#  'currently': 97,
#  'paging': 98,
#  'segmentation': 99,
#  'divided': 100,
#  'into': 101,
#  'calls': 102,
#  'examples': 103,
#  'concept': 104,
#  'context': 105,
#  'state': 106,
#  'shell': 107,
#  'interrupt': 108,
#  'task': 109,
#  'high': 110,
#  'symmetric': 111,
#  'asymmetric': 112,
#  'processors': 113,
#  'tasks': 114,
#  'hypervisor': 115,
#  'type': 116,
#  'runs': 117,
#  'advanced': 118,
#  'os': 119,
#  'acts': 120,
#  'computer': 121,
#  'basic': 122,
#  'functionality': 123,
#  'programs': 124,
#  'smooth': 125,
#  'scheduling': 126,
#  'allocating': 127,
#  'deallocating': 128,
#  'handling': 129,
#  'device': 130,
#  'input': 131,
#  'output': 132,
#  'protecting': 133,
#  'providing': 134,
#  '3': 135,
#  'independent': 136,
#  'program': 137,
#  'own': 138,
#  'managed': 139,
#  'smallest': 140,
#  'unit': 141,
#  'threads': 142,
#  '4': 143,
#  'technique': 144,
#  'gives': 145,
#  'application': 146,
#  'having': 147,
#  'large': 148,
#  'contiguous': 149,
#  'block': 150,
#  'even': 151,
#  'if': 152,
#  'physical': 153,
#  'limited': 154,
#  'disk': 155,
#  'extension': 156,
#  'ram': 157,
#  'allowing': 158,
#  'larger': 159,
#  '5': 160,
#  'purpose': 161,
#  'core': 162,
#  'part': 163,
#  'responsible': 164,
#  'such': 165,
#  'facilitates': 166,
#  'stability': 167,
#  '6': 168,
#  'different': 169,
#  'batch': 170,
#  'batches': 171,
#  'jobs': 172,
#  'without': 173,
#  'interaction': 174,
#  'group': 175,
#  'distinct': 176,
#  'computers': 177,
#  'appear': 178,
#  'single': 179,
#  'real': 180,
#  'rtos': 181,
#  'requiring': 182,
#  'precise': 183,
#  'timing': 184,
#  'reliability': 185,
#  'mobile': 186,
#  'smartphones': 187,
#  'tablets': 188,
#  'android': 189,
#  'ios': 190,
#  '7': 191,
#  'does': 192,
#  'work': 193,
#  'concurrently': 194,
#  'them': 195,
#  'rapidly': 196,
#  'scheduler': 197,
#  'allocate': 198,
#  'slices': 199,
#  'creating': 200,
#  'simultaneous': 201,
#  '8': 202,
#  'situation': 203,
#  'where': 204,
#  'set': 205,
#  'unable': 206,
#  'proceed': 207,
#  'because': 208,
#  'held': 209,
#  'this': 210,
#  'results': 211,
#  'standstill': 212,
#  '9': 213,
#  'describe': 214,
#  'includes': 215,
#  'new': 216,
#  'created': 217,
#  'ready': 218,
#  'be': 219,
#  'event': 220,
#  'terminated': 221,
#  'has': 222,
#  'completed': 223,
#  '10': 224,
#  'fixed': 225,
#  'size': 226,
#  'blocks': 227,
#  'called': 228,
#  'pages': 229,
#  'simplifies': 230,
#  'but': 231,
#  'may': 232,
#  'cause': 233,
#  'fragmentation': 234,
#  'variable': 235,
#  'sized': 236,
#  'segments': 237,
#  'based': 238,
#  'logical': 239,
#  'divisions': 240,
#  'like': 241,
#  'objects': 242,
#  'making': 243,
#  'more': 244,
#  '11': 245,
#  'why': 246,
#  'important': 247,
#  'method': 248,
#  'used': 249,
#  'organize': 250,
#  'store': 251,
#  'files': 252,
#  'mechanisms': 253,
#  'retrieval': 254,
#  'common': 255,
#  'ntfs': 256,
#  'fat32': 257,
#  'ext4': 258,
#  'etc': 259,
#  '12': 260,
#  'programming': 261,
#  'interfaces': 262,
#  'allow': 263,
#  'request': 264,
#  'services': 265,
#  'from': 266,
#  '13': 267,
#  'saving': 268,
#  'loading': 269,
#  'efficient': 270,
#  'utilization': 271,
#  '14': 272,
#  'executing': 273,
#  'commands': 274,
#  'bash': 275,
#  'linux': 276,
#  'command': 277,
#  'prompt': 278,
#  'windows': 279,
#  '15': 280,
#  'do': 281,
#  'through': 282,
#  'authentication': 283,
#  'encryption': 284,
#  'firewalls': 285,
#  'intrusion': 286,
#  'detection': 287,
#  'sandboxing': 288,
#  'regular': 289,
#  'updates': 290,
#  'patches': 291,
#  '16': 292,
#  'role': 293,
#  'signal': 294,
#  'informs': 295,
#  'stop': 296,
#  'current': 297,
#  'priority': 298,
#  'interrupts': 299,
#  'quick': 300,
#  'responses': 301,
#  'critical': 302,
#  'events': 303,
#  '17': 304,
#  'smp': 305,
#  'all': 306,
#  'equally': 307,
#  'amp': 308,
#  'assigned': 309,
#  'specific': 310,
#  'one': 311,
#  'processor': 312,
#  'typically': 313,
#  'acting': 314,
#  'master': 315,
#  '18': 316,
#  'creates': 317,
#  'machines': 318,
#  'abstracting': 319,
#  'directly': 320,
#  'vmware': 321,
#  'esxi': 322,
#  'host': 323,
#  'virtualbox': 324,
#  '19': 325,
#  'some': 326,
#  'features': 327,
#  'support': 328,
#  'multicore': 329,
#  'processing': 330,
#  'virtualization': 331,
#  'cloud': 332,
#  'integration': 333,
#  '20': 334,
#  'manage': 335,
#  'interconnected': 336,
#  'provide': 337,
#  'cohesive': 338,
#  'environment': 339,
#  'they': 340,
#  'enable': 341,
#  'load': 342,
#  'balancing': 343,
#  'fault': 344,
#  'tolerance': 345,
#  'across': 346,
#  'nodes': 347}

# %%
input_sequences = []
for sentence in docs.split('\n'):

    tokenized_sentence = tokenizer.texts_to_sequences([sentence])[0]
    for i in range(1, len(tokenized_sentence)):
        n_gram_sequence = tokenized_sentence[:i+1]
        input_sequences.append(n_gram_sequence)

# %%
input_sequences
# Out:
# [[8, 66],
#  [8, 66, 15],
#  [8, 66, 15, 4],
#  [8, 66, 15, 4, 12],
#  [8, 66, 15, 4, 12, 5],
#  [8, 66, 15, 4, 12, 5, 7],
#  [9, 12],
#  [9, 12, 5],
#  [9, 12, 5, 7],
#  [9, 12, 5, 7, 119],
#  [9, 12, 5, 7, 119, 4],
#  [9, 12, 5, 7, 119, 4, 2],
#  [9, 12, 5, 7, 119, 4, 2, 39],
#  [9, 12, 5, 7, 119, 4, 2, 39, 24],
#  [9, 12, 5, 7, 119, 4, 2, 39, 24, 120],
#  [9, 12, 5, 7, 119, 4, 2, 39, 24, 120, 27],
#  [9, 12, 5, 7, 119, 4, 2, 39, 24, 120, 27, 12],
#  [9, 12, 5, 7, 119, 4, 2, 39, 24, 120, 27, 12, 33],
#  [9, 12, 5, 7, 119, 4, 2, 39, 24, 120, 27, 12, 33, 25],
#  [9, 12, 5, 7, 119, 4, 2, 39, 24, 120, 27, 12, 33, 25, 121],
#  [9, 12, 5, 7, 119, 4, 2, 39, 24, 120, 27, 12, 33, 25, 121, 28],
#  [9, 12, 5, 7, 119, 4, 2, 39, 24, 120, 27, 12, 33, 25, 121, 28, 3],
#  [9, 12, 5, 7, 119, 4, 2, 39, 24, 120, 27, 12, 33, 25, 121, 28, 3, 1],
#  [9, 12, 5, 7, 119, 4, 2, 39, 24, 120, 27, 12, 33, 25, 121, 28, 3, 1, 20],
#  [9, 12, 5, 7, 119, 4, 2, 39, 24, 120, 27, 12, 33, 25, 121, 28, 3, 1, 20, 16],
#  [9,
#   12,
#   5,
#   7,
#   119,
#   4,
#   2,
#   39,
#   24,
#   120,
#   27,
#   12,
#   33,
#   25,
#   121,
#   28,
#   3,
#   1,
#   20,
#   16,
#   40],
#  [9,
#   12,
#   5,
#   7,
#   119,
#   4,
#   2,
#   39,
#   24,
#   120,
#   27,
#   12,
#   33,
#   25,
#   121,
#   28,
#   3,
#   1,
#   20,
#   16,
#   40,
#   28],
#  [9,
#   12,
#   5,
#   7,
#   119,
#   4,
#   2,
#   39,
#   24,
#   120,
#   27,
#   12,
#   33,
#   25,
#   121,
#   28,
#   3,
#   1,
#   20,
#   16,
#   40,
#   28,
#   29],
#  [9,
#   12,
#   5,
#   7,
#   119,
#   4,
#   2,
#   39,
#   24,
#   120,
#   27,
#   12,
#   33,
#   25,
#   121,
#   28,
#   3,
#   1,
#   20,
#   16,
#   40,
#   28,
#   29,
#   67],
#  [9,
#   12,
#   5,
#   7,
#   119,
#   4,
#   2,
#   39,
#   24,
#   120,
#   27,
#   12,
#   33,
#   25,
#   121,
#   28,
#   3,
#   1,
#   20,
#   16,
#   40,
#   28,
#   29,
#   67,
#   122],
#  [9,
#   12,
#   5,
#   7,
#   119,
#   4,
#   2,
#   39,
#   24,
#   120,
#   27,
#   12,
#   33,
#   25,
#   121,
#   28,
#   3,
#   1,
#   20,
#   16,
#   40,
#   28,
#   29,
#   67,
#   122,
#   123],
#  [9,
#   12,
#   5,
#   7,
#   119,
#   4,
#   2,
#   39,
#   24,
#   120,
#   27,
#   12,
#   33,
#   25,
#   121,
#   28,
#   3,
#   1,
#   20,
#   16,
#   40,
#   28,
#   29,
#   67,
#   122,
#   123,
#   13],
#  [9,
#   12,
#   5,
#   7,
#   119,
#   4,
#   2,
#   39,
#   24,
#   120,
#   27,
#   12,
#   33,
#   25,
#   121,
#   28,
#   3,
#   1,
#   20,
#   16,
#   40,
#   28,
#   29,
#   67,
#   122,
#   123,
#   13,
#   68],
#  [9,
#   12,
#   5,
#   7,
#   119,
#   4,
#   2,
#   39,
#   24,
#   120,
#   27,
#   12,
#   33,
#   25,
#   121,
#   28,
#   3,
#   1,
#   20,
#   16,
#   40,
#   28,
#   29,
#   67,
#   122,
#   123,
#   13,
#   68,
#   124],
#  [9,
#   12,
#   5,
#   7,
#   119,
#   4,
#   2,
#   39,
#   24,
#   120,
#   27,
#   12,
#   33,
#   25,
#   121,
#   28,
#   3,
#   1,
#   20,
#   16,
#   40,
#   28,
#   29,
#   67,
#   122,
#   123,
#   13,
#   68,
#   124,
#   3],
#  [9,
#   12,
#   5,
#   7,
#   119,
#   4,
#   2,
#   39,
#   24,
#   120,
#   27,
#   12,
#   33,
#   25,
#   121,
#   28,
#   3,
#   1,
#   20,
#   16,
#   40,
#   28,
#   29,
#   67,
#   122,
#   123,
#   13,
#   68,
#   124,
#   3,
#   69],
#  [9,
#   12,
#   5,
#   7,
#   119,
#   4,
#   2,
#   39,
#   24,
#   120,
#   27,
#   12,
#   33,
#   25,
#   121,
#   28,
#   3,
#   1,
#   20,
#   16,
#   40,
#   28,
#   29,
#   67,
#   122,
#   123,
#   13,
#   68,
#   124,
#   3,
#   69,
#   125],
#  [9,
#   12,
#   5,
#   7,
#   119,
#   4,
#   2,
#   39,
#   24,
#   120,
#   27,
#   12,
#   33,
#   25,
#   121,
#   28,
#   3,
#   1,
#   20,
#   16,
#   40,
#   28,
#   29,
#   67,
#   122,
#   123,
#   13,
#   68,
#   124,
#   3,
#   69,
#   125,
#   34],
#  [9,
#   12,
#   5,
#   7,
#   119,
#   4,
#   2,
#   39,
#   24,
#   120,
#   27,
#   12,
#   33,
#   25,
#   121,
#   28,
#   3,
#   1,
#   20,
#   16,
#   40,
#   28,
#   29,
#   67,
#   122,
#   123,
#   13,
#   68,
#   124,
#   3,
#   69,
#   125,
#   34,
#   6],
#  [9,
#   12,
#   5,
#   7,
#   119,
#   4,
#   2,
#   39,
#   24,
#   120,
#   27,
#   12,
#   33,
#   25,
#   121,
#   28,
#   3,
#   1,
#   20,
#   16,
#   40,
#   28,
#   29,
#   67,
#   122,
#   123,
#   13,
#   68,
#   124,
#   3,
#   69,
#   125,
#   34,
#   6,
#   26],
#  [9,
#   12,
#   5,
#   7,
#   119,
#   4,
#   2,
#   39,
#   24,
#   120,
#   27,
#   12,
#   33,
#   25,
#   121,
#   28,
#   3,
#   1,
#   20,
#   16,
#   40,
#   28,
#   29,
#   67,
#   122,
#   123,
#   13,
#   68,
#   124,
#   3,
#   69,
#   125,
#   34,
#   6,
#   26,
#   30],
#  [8, 70],
#  [8, 70, 15],
#  [8, 70, 15, 18],
#  [8, 70, 15, 18, 1],
#  [8, 70, 15, 18, 1, 71],
#  [8, 70, 15, 18, 1, 71, 41],
#  [8, 70, 15, 18, 1, 71, 41, 6],
#  [8, 70, 15, 18, 1, 71, 41, 6, 12],
#  [8, 70, 15, 18, 1, 71, 41, 6, 12, 5],
#  [8, 70, 15, 18, 1, 71, 41, 6, 12, 5, 7],
#  [9, 1],
#  [9, 1, 71],
#  [9, 1, 71, 41],
#  [9, 1, 71, 41, 6],
#  [9, 1, 71, 41, 6, 12],
#  [9, 1, 71, 41, 6, 12, 5],
#  [9, 1, 71, 41, 6, 12, 5, 7],
#  [9, 1, 71, 41, 6, 12, 5, 7, 31],
#  [10, 19],
#  [10, 19, 126],
#  [10, 19, 126, 3],
#  [10, 19, 126, 3, 42],
#  [10, 19, 126, 3, 42, 35],
#  [14, 19],
#  [14, 19, 127],
#  [14, 19, 127, 3],
#  [14, 19, 127, 3, 128],
#  [14, 19, 127, 3, 128, 14],
#  [21, 7],
#  [21, 7, 19],
#  [21, 7, 19, 129],
#  [21, 7, 19, 129, 21],
#  [21, 7, 19, 129, 21, 72],
#  [21, 7, 19, 129, 21, 72, 3],
#  [21, 7, 19, 129, 21, 72, 3, 43],
#  [130, 19],
#  [130, 19, 42],
#  [130, 19, 42, 131],
#  [130, 19, 42, 131, 132],
#  [130, 19, 42, 131, 132, 44],
#  [45, 3],
#  [45, 3, 46],
#  [45, 3, 46, 47],
#  [45, 3, 46, 47, 133],
#  [45, 3, 46, 47, 133, 48],
#  [45, 3, 46, 47, 133, 48, 3],
#  [45, 3, 46, 47, 133, 48, 3, 29],
#  [20, 33],
#  [20, 33, 134],
#  [20, 33, 134, 2],
#  [20, 33, 134, 2, 20],
#  [20, 33, 134, 2, 20, 73],
#  [20, 33, 134, 2, 20, 73, 33],
#  [8, 135],
#  [8, 135, 15],
#  [8, 135, 15, 4],
#  [8, 135, 15, 4, 1],
#  [8, 135, 15, 4, 1, 49],
#  [8, 135, 15, 4, 1, 49, 25],
#  [8, 135, 15, 4, 1, 49, 25, 2],
#  [8, 135, 15, 4, 1, 49, 25, 2, 10],
#  [8, 135, 15, 4, 1, 49, 25, 2, 10, 3],
#  [8, 135, 15, 4, 1, 49, 25, 2, 10, 3, 2],
#  [8, 135, 15, 4, 1, 49, 25, 2, 10, 3, 2, 50],
#  [10, 2],
#  [10, 2, 10],
#  [10, 2, 10, 4],
#  [10, 2, 10, 4, 12],
#  [10, 2, 10, 4, 12, 136],
#  [10, 2, 10, 4, 12, 136, 137],
#  [10, 2, 10, 4, 12, 136, 137, 17],
#  [10, 2, 10, 4, 12, 136, 137, 17, 34],
#  [10, 2, 10, 4, 12, 136, 137, 17, 34, 51],
#  [10, 2, 10, 4, 12, 136, 137, 17, 34, 51, 74],
#  [10, 2, 10, 4, 12, 136, 137, 17, 34, 51, 74, 138],
#  [10, 2, 10, 4, 12, 136, 137, 17, 34, 51, 74, 138, 14],
#  [10, 2, 10, 4, 12, 136, 137, 17, 34, 51, 74, 138, 14, 75],
#  [10, 2, 10, 4, 12, 136, 137, 17, 34, 51, 74, 138, 14, 75, 16],
#  [10, 2, 10, 4, 12, 136, 137, 17, 34, 51, 74, 138, 14, 75, 16, 4],
#  [10, 2, 10, 4, 12, 136, 137, 17, 34, 51, 74, 138, 14, 75, 16, 4, 139],
#  [10, 2, 10, 4, 12, 136, 137, 17, 34, 51, 74, 138, 14, 75, 16, 4, 139, 22],
#  [10, 2, 10, 4, 12, 136, 137, 17, 34, 51, 74, 138, 14, 75, 16, 4, 139, 22, 1],
#  [10,
#   2,
#   10,
#   4,
#   12,
#   136,
#   137,
#   17,
#   34,
#   51,
#   74,
#   138,
#   14,
#   75,
#   16,
#   4,
#   139,
#   22,
#   1,
#   5],
#  [10,
#   2,
#   10,
#   4,
#   12,
#   136,
#   137,
#   17,
#   34,
#   51,
#   74,
#   138,
#   14,
#   75,
#   16,
#   4,
#   139,
#   22,
#   1,
#   5,
#   7],
#  [50, 2],
#  [50, 2, 50],
#  [50, 2, 50, 4],
#  [50, 2, 50, 4, 1],
#  [50, 2, 50, 4, 1, 140],
#  [50, 2, 50, 4, 1, 140, 141],
#  [50, 2, 50, 4, 1, 140, 141, 6],
#  [50, 2, 50, 4, 1, 140, 141, 6, 2],
#  [50, 2, 50, 4, 1, 140, 141, 6, 2, 10],
#  [50, 2, 50, 4, 1, 140, 141, 6, 2, 10, 26],
#  [50, 2, 50, 4, 1, 140, 141, 6, 2, 10, 26, 142],
#  [50, 2, 50, 4, 1, 140, 141, 6, 2, 10, 26, 142, 6],
#  [50, 2, 50, 4, 1, 140, 141, 6, 2, 10, 26, 142, 6, 2],
#  [50, 2, 50, 4, 1, 140, 141, 6, 2, 10, 26, 142, 6, 2, 10],
#  [50, 2, 50, 4, 1, 140, 141, 6, 2, 10, 26, 142, 6, 2, 10, 76],
#  [50, 2, 50, 4, 1, 140, 141, 6, 2, 10, 26, 142, 6, 2, 10, 76, 1],
#  [50, 2, 50, 4, 1, 140, 141, 6, 2, 10, 26, 142, 6, 2, 10, 76, 1, 77],
#  [50, 2, 50, 4, 1, 140, 141, 6, 2, 10, 26, 142, 6, 2, 10, 76, 1, 77, 14],
#  [50, 2, 50, 4, 1, 140, 141, 6, 2, 10, 26, 142, 6, 2, 10, 76, 1, 77, 14, 3],
#  [50,
#   2,
#   50,
#   4,
#   1,
#   140,
#   141,
#   6,
#   2,
#   10,
#   26,
#   142,
#   6,
#   2,
#   10,
#   76,
#   1,
#   77,
#   14,
#   3,
#   29],
#  [8, 143],
#  [8, 143, 52],
#  [8, 143, 52, 53],
#  [8, 143, 52, 53, 14],
#  [9, 53],
#  [9, 53, 14],
#  [9, 53, 14, 4],
#  [9, 53, 14, 4, 2],
#  [9, 53, 14, 4, 2, 14],
#  [9, 53, 14, 4, 2, 14, 19],
#  [9, 53, 14, 4, 2, 14, 19, 144],
#  [9, 53, 14, 4, 2, 14, 19, 144, 24],
#  [9, 53, 14, 4, 2, 14, 19, 144, 24, 145],
#  [9, 53, 14, 4, 2, 14, 19, 144, 24, 145, 12],
#  [9, 53, 14, 4, 2, 14, 19, 144, 24, 145, 12, 146],
#  [9, 53, 14, 4, 2, 14, 19, 144, 24, 145, 12, 146, 1],
#  [9, 53, 14, 4, 2, 14, 19, 144, 24, 145, 12, 146, 1, 78],
#  [9, 53, 14, 4, 2, 14, 19, 144, 24, 145, 12, 146, 1, 78, 6],
#  [9, 53, 14, 4, 2, 14, 19, 144, 24, 145, 12, 146, 1, 78, 6, 147],
#  [9, 53, 14, 4, 2, 14, 19, 144, 24, 145, 12, 146, 1, 78, 6, 147, 2],
#  [9, 53, 14, 4, 2, 14, 19, 144, 24, 145, 12, 146, 1, 78, 6, 147, 2, 148],
#  [9, 53, 14, 4, 2, 14, 19, 144, 24, 145, 12, 146, 1, 78, 6, 147, 2, 148, 149],
#  [9,
#   53,
#   14,
#   4,
#   2,
#   14,
#   19,
#   144,
#   24,
#   145,
#   12,
#   146,
#   1,
#   78,
#   6,
#   147,
#   2,
#   148,
#   149,
#   150],
#  [9,
#   53,
#   14,
#   4,
#   2,
#   14,
#   19,
#   144,
#   24,
#   145,
#   12,
#   146,
#   1,
#   78,
#   6,
#   147,
#   2,
#   148,
#   149,
#   150,
#   6],
#  [9,
#   53,
#   14,
#   4,
#   2,
#   14,
#   19,
#   144,
#   24,
#   145,
#   12,
#   146,
#   1,
#   78,
#   6,
#   147,
#   2,
#   148,
#   149,
#   150,
#   6,
#   14],
#  [9,
#   53,
#   14,
#   4,
#   2,
#   14,
#   19,
#   144,
#   24,
#   145,
#   12,
#   146,
#   1,
#   78,
#   6,
#   147,
#   2,
#   148,
#   149,
#   150,
#   6,
#   14,
#   151],
#  [9,
#   53,
#   14,
#   4,
#   2,
#   14,
#   19,
#   144,
#   24,
#   145,
#   12,
#   146,
#   1,
#   78,
#   6,
#   147,
#   2,
#   148,
#   149,
#   150,
#   6,
#   14,
#   151,
#   152],
#  [9,
#   53,
#   14,
#   4,
#   2,
#   14,
#   19,
#   144,
#   24,
#   145,
#   12,
#   146,
#   1,
#   78,
#   6,
#   147,
#   2,
#   148,
#   149,
#   150,
#   6,
#   14,
#   151,
#   152,
#   1],
#  [9,
#   53,
#   14,
#   4,
#   2,
#   14,
#   19,
#   144,
#   24,
#   145,
#   12,
#   146,
#   1,
#   78,
#   6,
#   147,
#   2,
#   148,
#   149,
#   150,
#   6,
#   14,
#   151,
#   152,
#   1,
#   153],
#  [9,
#   53,
#   14,
#   4,
#   2,
#   14,
#   19,
#   144,
#   24,
#   145,
#   12,
#   146,
#   1,
#   78,
#   6,
#   147,
#   2,
#   148,
#   149,
#   150,
#   6,
#   14,
#   151,
#   152,
#   1,
#   153,
#   14],
#  [9,
#   53,
#   14,
#   4,
#   2,
#   14,
#   19,
#   144,
#   24,
#   145,
#   12,
#   146,
#   1,
#   78,
#   6,
#   147,
#   2,
#   148,
#   149,
#   150,
#   6,
#   14,
#   151,
#   152,
#   1,
#   153,
#   14,
#   4],
#  [9,
#   53,
#   14,
#   4,
#   2,
#   14,
#   19,
#   144,
#   24,
#   145,
#   12,
#   146,
#   1,
#   78,
#   6,
#   147,
#   2,
#   148,
#   149,
#   150,
#   6,
#   14,
#   151,
#   152,
#   1,
#   153,
#   14,
#   4,
#   154],
#  [9,
#   53,
#   14,
#   4,
#   2,
#   14,
#   19,
#   144,
#   24,
#   145,
#   12,
#   146,
#   1,
#   78,
#   6,
#   147,
#   2,
#   148,
#   149,
#   150,
#   6,
#   14,
#   151,
#   152,
#   1,
#   153,
#   14,
#   4,
#   154,
#   16],
#  [9,
#   53,
#   14,
#   4,
#   2,
#   14,
#   19,
#   144,
#   24,
#   145,
#   12,
#   146,
#   1,
#   78,
#   6,
#   147,
#   2,
#   148,
#   149,
#   150,
#   6,
#   14,
#   151,
#   152,
#   1,
#   153,
#   14,
#   4,
#   154,
#   16,
#   79],
#  [9,
#   53,
#   14,
#   4,
#   2,
#   14,
#   19,
#   144,
#   24,
#   145,
#   12,
#   146,
#   1,
#   78,
#   6,
#   147,
#   2,
#   148,
#   149,
#   150,
#   6,
#   14,
#   151,
#   152,
#   1,
#   153,
#   14,
#   4,
#   154,
#   16,
#   79,
#   155],
#  [9,
#   53,
#   14,
#   4,
#   2,
#   14,
#   19,
#   144,
#   24,
#   145,
#   12,
#   146,
#   1,
#   78,
#   6,
#   147,
#   2,
#   148,
#   149,
#   150,
#   6,
#   14,
#   151,
#   152,
#   1,
#   153,
#   14,
#   4,
#   154,
#   16,
#   79,
#   155,
#   75],
#  [9,
#   53,
#   14,
#   4,
#   2,
#   14,
#   19,
#   144,
#   24,
#   145,
#   12,
#   146,
#   1,
#   78,
#   6,
#   147,
#   2,
#   148,
#   149,
#   150,
#   6,
#   14,
#   151,
#   152,
#   1,
#   153,
#   14,
#   4,
#   154,
#   16,
#   79,
#   155,
#   75,
#   27],
#  [9,
#   53,
#   14,
#   4,
#   2,
#   14,
#   19,
#   144,
#   24,
#   145,
#   12,
#   146,
#   1,
#   78,
#   6,
#   147,
#   2,
#   148,
#   149,
#   150,
#   6,
#   14,
#   151,
#   152,
#   1,
#   153,
#   14,
#   4,
#   154,
#   16,
#   79,
#   155,
#   75,
#   27,
#   12],
#  [9,
#   53,
#   14,
#   4,
#   2,
#   14,
#   19,
#   144,
#   24,
#   145,
#   12,
#   146,
#   1,
#   78,
#   6,
#   147,
#   2,
#   148,
#   149,
#   150,
#   6,
#   14,
#   151,
#   152,
#   1,
#   153,
#   14,
#   4,
#   154,
#   16,
#   79,
#   155,
#   75,
#   27,
#   12,
#   156],
#  [9,
#   53,
#   14,
#   4,
#   2,
#   14,
#   19,
#   144,
#   24,
#   145,
#   12,
#   146,
#   1,
#   78,
#   6,
#   147,
#   2,
#   148,
#   149,
#   150,
#   6,
#   14,
#   151,
#   152,
#   1,
#   153,
#   14,
#   4,
#   154,
#   16,
#   79,
#   155,
#   75,
#   27,
#   12,
#   156,
#   6],
#  [9,
#   53,
#   14,
#   4,
#   2,
#   14,
#   19,
#   144,
#   24,
#   145,
#   12,
#   146,
#   1,
#   78,
#   6,
#   147,
#   2,
#   148,
#   149,
#   150,
#   6,
#   14,
#   151,
#   152,
#   1,
#   153,
#   14,
#   4,
#   154,
#   16,
#   79,
#   155,
#   75,
#   27,
#   12,
#   156,
#   6,
#   157],
#  [9,
#   53,
#   14,
#   4,
#   2,
#   14,
#   19,
#   144,
#   24,
#   145,
#   12,
#   146,
#   1,
#   78,
#   6,
#   147,
#   2,
#   148,
#   149,
#   150,
#   6,
#   14,
#   151,
#   152,
#   1,
#   153,
#   14,
#   4,
#   154,
#   16,
#   79,
#   155,
#   75,
#   27,
#   12,
#   156,
#   6,
#   157,
#   158],
#  [9,
#   53,
#   14,
#   4,
#   2,
#   14,
#   19,
#   144,
#   24,
#   145,
#   12,
#   146,
#   1,
#   78,
#   6,
#   147,
#   2,
#   148,
#   149,
#   150,
#   6,
#   14,
#   151,
#   152,
#   1,
#   153,
#   14,
#   4,
#   154,
#   16,
#   79,
#   155,
#   75,
#   27,
#   12,
#   156,
#   6,
#   157,
#   158,
#   11],
#  [9,
#   53,
#   14,
#   4,
#   2,
#   14,
#   19,
#   144,
#   24,
#   145,
#   12,
#   146,
#   1,
#   78,
#   6,
#   147,
#   2,
#   148,
#   149,
#   150,
#   6,
#   14,
#   151,
#   152,
#   1,
#   153,
#   14,
#   4,
#   154,
#   16,
#   79,
#   155,
#   75,
#   27,
#   12,
#   156,
#   6,
#   157,
#   158,
#   11,
#   13],
#  [9,
#   53,
#   14,
#   4,
#   2,
#   14,
#   19,
#   144,
#   24,
#   145,
#   12,
#   146,
#   1,
#   78,
#   6,
#   147,
#   2,
#   148,
#   149,
#   150,
#   6,
#   14,
#   151,
#   152,
#   1,
#   153,
#   14,
#   4,
#   154,
#   16,
#   79,
#   155,
#   75,
#   27,
#   12,
#   156,
#   6,
#   157,
#   158,
#   11,
#   13,
#   80],
#  [9,
#   53,
#   14,
#   4,
#   2,
#   14,
#   19,
#   144,
#   24,
#   145,
#   12,
#   146,
#   1,
#   78,
#   6,
#   147,
#   2,
#   148,
#   149,
#   150,
#   6,
#   14,
#   151,
#   152,
#   1,
#   153,
#   14,
#   4,
#   154,
#   16,
#   79,
#   155,
#   75,
#   27,
#   12,
#   156,
#   6,
#   157,
#   158,
#   11,
#   13,
#   80,
#   159],
#  [9,
#   53,
#   14,
#   4,
#   2,
#   14,
#   19,
#   144,
#   24,
#   145,
#   12,
#   146,
#   1,
#   78,
#   6,
#   147,
#   2,
#   148,
#   149,
#   150,
#   6,
#   14,
#   151,
#   152,
#   1,
#   153,
#   14,
#   4,
#   154,
#   16,
#   79,
#   155,
#   75,
#   27,
#   12,
#   156,
#   6,
#   157,
#   158,
#   11,
#   13,
#   80,
#   159,
#   30],
#  [9,
#   53,
#   14,
#   4,
#   2,
#   14,
#   19,
#   144,
#   24,
#   145,
#   12,
#   146,
#   1,
#   78,
#   6,
#   147,
#   2,
#   148,
#   149,
#   150,
#   6,
#   14,
#   151,
#   152,
#   1,
#   153,
#   14,
#   4,
#   154,
#   16,
#   79,
#   155,
#   75,
#   27,
#   12,
#   156,
#   6,
#   157,
#   158,
#   11,
#   13,
#   80,
#   159,
#   30,
#   54],
#  [9,
#   53,
#   14,
#   4,
#   2,
#   14,
#   19,
#   144,
#   24,
#   145,
#   12,
#   146,
#   1,
#   78,
#   6,
#   147,
#   2,
#   148,
#   149,
#   150,
#   6,
#   14,
#   151,
#   152,
#   1,
#   153,
#   14,
#   4,
#   154,
#   16,
#   79,
#   155,
#   75,
#   27,
#   12,
#   156,
#   6,
#   157,
#   158,
#   11,
#   13,
#   80,
#   159,
#   30,
#   54,
#   26],
#  [9,
#   53,
#   14,
#   4,
#   2,
#   14,
#   19,
#   144,
#   24,
#   145,
#   12,
#   146,
#   1,
#   78,
#   6,
#   147,
#   2,
#   148,
#   149,
#   150,
#   6,
#   14,
#   151,
#   152,
#   1,
#   153,
#   14,
#   4,
#   154,
#   16,
#   79,
#   155,
#   75,
#   27,
#   12,
#   156,
#   6,
#   157,
#   158,
#   11,
#   13,
#   80,
#   159,
#   30,
#   54,
#   26,
#   30],
#  [9,
#   53,
#   14,
#   4,
#   2,
#   14,
#   19,
#   144,
#   24,
#   145,
#   12,
#   146,
#   1,
#   78,
#   6,
#   147,
#   2,
#   148,
#   149,
#   150,
#   6,
#   14,
#   151,
#   152,
#   1,
#   153,
#   14,
#   4,
#   154,
#   16,
#   79,
#   155,
#   75,
#   27,
#   12,
#   156,
#   6,
#   157,
#   158,
#   11,
#   13,
#   80,
#   159,
#   30,
#   54,
#   26,
#   30,
#   81],
#  [8, 160],
#  [8, 160, 15],
#  [8, 160, 15, 4],
#  [8, 160, 15, 4, 1],
#  [8, 160, 15, 4, 1, 161],
#  [8, 160, 15, 4, 1, 161, 6],
#  [8, 160, 15, 4, 1, 161, 6, 2],
#  [8, 160, 15, 4, 1, 161, 6, 2, 55],
#  [8, 160, 15, 4, 1, 161, 6, 2, 55, 17],
#  [8, 160, 15, 4, 1, 161, 6, 2, 55, 17, 12],
#  [8, 160, 15, 4, 1, 161, 6, 2, 55, 17, 12, 5],
#  [8, 160, 15, 4, 1, 161, 6, 2, 55, 17, 12, 5, 7],
#  [9, 1],
#  [9, 1, 55],
#  [9, 1, 55, 4],
#  [9, 1, 55, 4, 1],
#  [9, 1, 55, 4, 1, 162],
#  [9, 1, 55, 4, 1, 162, 163],
#  [9, 1, 55, 4, 1, 162, 163, 6],
#  [9, 1, 55, 4, 1, 162, 163, 6, 1],
#  [9, 1, 55, 4, 1, 162, 163, 6, 1, 5],
#  [9, 1, 55, 4, 1, 162, 163, 6, 1, 5, 7],
#  [9, 1, 55, 4, 1, 162, 163, 6, 1, 5, 7, 164],
#  [9, 1, 55, 4, 1, 162, 163, 6, 1, 5, 7, 164, 23],
#  [9, 1, 55, 4, 1, 162, 163, 6, 1, 5, 7, 164, 23, 42],
#  [9, 1, 55, 4, 1, 162, 163, 6, 1, 5, 7, 164, 23, 42, 7],
#  [9, 1, 55, 4, 1, 162, 163, 6, 1, 5, 7, 164, 23, 42, 7, 29],
#  [9, 1, 55, 4, 1, 162, 163, 6, 1, 5, 7, 164, 23, 42, 7, 29, 165],
#  [9, 1, 55, 4, 1, 162, 163, 6, 1, 5, 7, 164, 23, 42, 7, 29, 165, 27],
#  [9, 1, 55, 4, 1, 162, 163, 6, 1, 5, 7, 164, 23, 42, 7, 29, 165, 27, 32],
#  [9, 1, 55, 4, 1, 162, 163, 6, 1, 5, 7, 164, 23, 42, 7, 29, 165, 27, 32, 14],
#  [9,
#   1,
#   55,
#   4,
#   1,
#   162,
#   163,
#   6,
#   1,
#   5,
#   7,
#   164,
#   23,
#   42,
#   7,
#   29,
#   165,
#   27,
#   32,
#   14,
#   3],
#  [9,
#   1,
#   55,
#   4,
#   1,
#   162,
#   163,
#   6,
#   1,
#   5,
#   7,
#   164,
#   23,
#   42,
#   7,
#   29,
#   165,
#   27,
#   32,
#   14,
#   3,
#   44],
#  [9,
#   1,
#   55,
#   4,
#   1,
#   162,
#   163,
#   6,
#   1,
#   5,
#   7,
#   164,
#   23,
#   42,
#   7,
#   29,
#   165,
#   27,
#   32,
#   14,
#   3,
#   44,
#   16],
#  [9,
#   1,
#   55,
#   4,
#   1,
#   162,
#   163,
#   6,
#   1,
#   5,
#   7,
#   164,
#   23,
#   42,
#   7,
#   29,
#   165,
#   27,
#   32,
#   14,
#   3,
#   44,
#   16,
#   166],
#  [9,
#   1,
#   55,
#   4,
#   1,
#   162,
#   163,
#   6,
#   1,
#   5,
#   7,
#   164,
#   23,
#   42,
#   7,
#   29,
#   165,
#   27,
#   32,
#   14,
#   3,
#   44,
#   16,
#   166,
#   82],
#  [9,
#   1,
#   55,
#   4,
#   1,
#   162,
#   163,
#   6,
#   1,
#   5,
#   7,
#   164,
#   23,
#   42,
#   7,
#   29,
#   165,
#   27,
#   32,
#   14,
#   3,
#   44,
#   16,
#   166,
#   82,
#   25],
#  [9,
#   1,
#   55,
#   4,
#   1,
#   162,
#   163,
#   6,
#   1,
#   5,
#   7,
#   164,
#   23,
#   42,
#   7,
#   29,
#   165,
#   27,
#   32,
#   14,
#   3,
#   44,
#   16,
#   166,
#   82,
#   25,
#   28],
#  [9,
#   1,
#   55,
#   4,
#   1,
#   162,
#   163,
#   6,
#   1,
#   5,
#   7,
#   164,
#   23,
#   42,
#   7,
#   29,
#   165,
#   27,
#   32,
#   14,
#   3,
#   44,
#   16,
#   166,
#   82,
#   25,
#   28,
#   3],
#  [9,
#   1,
#   55,
#   4,
#   1,
#   162,
#   163,
#   6,
#   1,
#   5,
#   7,
#   164,
#   23,
#   42,
#   7,
#   29,
#   165,
#   27,
#   32,
#   14,
#   3,
#   44,
#   16,
#   166,
#   82,
#   25,
#   28,
#   3,
#   39],
#  [9,
#   1,
#   55,
#   4,
#   1,
#   162,
#   163,
#   6,
#   1,
#   5,
#   7,
#   164,
#   23,
#   42,
#   7,
#   29,
#   165,
#   27,
#   32,
#   14,
#   3,
#   44,
#   16,
#   166,
#   82,
#   25,
#   28,
#   3,
#   39,
#   3],
#  [9,
#   1,
#   55,
#   4,
#   1,
#   162,
#   163,
#   6,
#   1,
#   5,
#   7,
#   164,
#   23,
#   42,
#   7,
#   29,
#   165,
#   27,
#   32,
#   14,
#   3,
#   44,
#   16,
#   166,
#   82,
#   25,
#   28,
#   3,
#   39,
#   3,
#   69],
#  [9,
#   1,
#   55,
#   4,
#   1,
#   162,
#   163,
#   6,
#   1,
#   5,
#   7,
#   164,
#   23,
#   42,
#   7,
#   29,
#   165,
#   27,
#   32,
#   14,
#   3,
#   44,
#   16,
#   166,
#   82,
#   25,
#   28,
#   3,
#   39,
#   3,
#   69,
#   7],
#  [9,
#   1,
#   55,
#   4,
#   1,
#   162,
#   163,
#   6,
#   1,
#   5,
#   7,
#   164,
#   23,
#   42,
#   7,
#   29,
#   165,
#   27,
#   32,
#   14,
#   3,
#   44,
#   16,
#   166,
#   82,
#   25,
#   28,
#   3,
#   39,
#   3,
#   69,
#   7,
#   167],
#  [9,
#   1,
#   55,
#   4,
#   1,
#   162,
#   163,
#   6,
#   1,
#   5,
#   7,
#   164,
#   23,
#   42,
#   7,
#   29,
#   165,
#   27,
#   32,
#   14,
#   3,
#   44,
#   16,
#   166,
#   82,
#   25,
#   28,
#   3,
#   39,
#   3,
#   69,
#   7,
#   167,
#   3],
#  [9,
#   1,
#   55,
#   4,
#   1,
#   162,
#   163,
#   6,
#   1,
#   5,
#   7,
#   164,
#   23,
#   42,
#   7,
#   29,
#   165,
#   27,
#   32,
#   14,
#   3,
#   44,
#   16,
#   166,
#   82,
#   25,
#   28,
#   3,
#   39,
#   3,
#   69,
#   7,
#   167,
#   3,
#   83],
#  [8, 168],
#  [8, 168, 15],
#  [8, 168, 15, 18],
#  [8, 168, 15, 18, 1],
#  [8, 168, 15, 18, 1, 169],
#  [8, 168, 15, 18, 1, 169, 84],
#  [8, 168, 15, 18, 1, 169, 84, 6],
#  [8, 168, 15, 18, 1, 169, 84, 6, 5],
#  [8, 168, 15, 18, 1, 169, 84, 6, 5, 11],
#  [170, 5],
#  [170, 5, 11],
#  [170, 5, 11, 35],
#  [170, 5, 11, 35, 171],
#  [170, 5, 11, 35, 171, 6],
#  [170, 5, 11, 35, 171, 6, 172],
#  [170, 5, 11, 35, 171, 6, 172, 173],
#  [170, 5, 11, 35, 171, 6, 172, 173, 20],
#  [170, 5, 11, 35, 171, 6, 172, 173, 20, 174],
#  [56, 85],
#  [56, 85, 5],
#  [56, 85, 5, 11],
#  [56, 85, 5, 11, 36],
#  [56, 85, 5, 11, 36, 26],
#  [56, 85, 5, 11, 36, 26, 86],
#  [56, 85, 5, 11, 36, 26, 86, 13],
#  [56, 85, 5, 11, 36, 26, 86, 13, 87],
#  [56, 85, 5, 11, 36, 26, 86, 13, 87, 81],
#  [57, 5],
#  [57, 5, 11],
#  [57, 5, 11, 40],
#  [57, 5, 11, 40, 2],
#  [57, 5, 11, 40, 2, 175],
#  [57, 5, 11, 40, 2, 175, 6],
#  [57, 5, 11, 40, 2, 175, 6, 176],
#  [57, 5, 11, 40, 2, 175, 6, 176, 177],
#  [57, 5, 11, 40, 2, 175, 6, 176, 177, 13],
#  [57, 5, 11, 40, 2, 175, 6, 176, 177, 13, 178],
#  [57, 5, 11, 40, 2, 175, 6, 176, 177, 13, 178, 27],
#  [57, 5, 11, 40, 2, 175, 6, 176, 177, 13, 178, 27, 2],
#  [57, 5, 11, 40, 2, 175, 6, 176, 177, 13, 178, 27, 2, 179],
#  [57, 5, 11, 40, 2, 175, 6, 176, 177, 13, 178, 27, 2, 179, 7],
#  [180, 56],
#  [180, 56, 5],
#  [180, 56, 5, 11],
#  [180, 56, 5, 11, 181],
#  [180, 56, 5, 11, 181, 88],
#  [180, 56, 5, 11, 181, 88, 23],
#  [180, 56, 5, 11, 181, 88, 23, 11],
#  [180, 56, 5, 11, 181, 88, 23, 11, 182],
#  [180, 56, 5, 11, 181, 88, 23, 11, 182, 183],
#  [180, 56, 5, 11, 181, 88, 23, 11, 182, 183, 184],
#  [180, 56, 5, 11, 181, 88, 23, 11, 182, 183, 184, 3],
#  [180, 56, 5, 11, 181, 88, 23, 11, 182, 183, 184, 3, 185],
#  [186, 5],
#  [186, 5, 11],
#  [186, 5, 11, 88],
#  [186, 5, 11, 88, 23],
#  [186, 5, 11, 88, 23, 187],
#  [186, 5, 11, 88, 23, 187, 3],
#  [186, 5, 11, 88, 23, 187, 3, 188],
#  [186, 5, 11, 88, 23, 187, 3, 188, 58],
#  [186, 5, 11, 88, 23, 187, 3, 188, 58, 59],
#  [186, 5, 11, 88, 23, 187, 3, 188, 58, 59, 189],
#  [186, 5, 11, 88, 23, 187, 3, 188, 58, 59, 189, 190],
#  [8, 191],
#  [8, 191, 89],
#  [8, 191, 89, 192],
#  [8, 191, 89, 192, 60],
#  [8, 191, 89, 192, 60, 193],
#  [8, 191, 89, 192, 60, 193, 17],
#  [8, 191, 89, 192, 60, 193, 17, 12],
#  [8, 191, 89, 192, 60, 193, 17, 12, 5],
#  [8, 191, 89, 192, 60, 193, 17, 12, 5, 7],
#  [9, 60],
#  [9, 60, 36],
#  [9, 60, 36, 26],
#  [9, 60, 36, 26, 35],
#  [9, 60, 36, 26, 35, 13],
#  [9, 60, 36, 26, 35, 13, 80],
#  [9, 60, 36, 26, 35, 13, 80, 194],
#  [9, 60, 36, 26, 35, 13, 80, 194, 22],
#  [9, 60, 36, 26, 35, 13, 80, 194, 22, 61],
#  [9, 60, 36, 26, 35, 13, 80, 194, 22, 61, 25],
#  [9, 60, 36, 26, 35, 13, 80, 194, 22, 61, 25, 195],
#  [9, 60, 36, 26, 35, 13, 80, 194, 22, 61, 25, 195, 196],
#  [9, 60, 36, 26, 35, 13, 80, 194, 22, 61, 25, 195, 196, 1],
#  [9, 60, 36, 26, 35, 13, 80, 194, 22, 61, 25, 195, 196, 1, 5],
#  [9, 60, 36, 26, 35, 13, 80, 194, 22, 61, 25, 195, 196, 1, 5, 7],
#  [9, 60, 36, 26, 35, 13, 80, 194, 22, 61, 25, 195, 196, 1, 5, 7, 79],
#  [9, 60, 36, 26, 35, 13, 80, 194, 22, 61, 25, 195, 196, 1, 5, 7, 79, 2],
#  [9, 60, 36, 26, 35, 13, 80, 194, 22, 61, 25, 195, 196, 1, 5, 7, 79, 2, 197],
#  [9,
#   60,
#   36,
#   26,
#   35,
#   13,
#   80,
#   194,
#   22,
#   61,
#   25,
#   195,
#   196,
#   1,
#   5,
#   7,
#   79,
#   2,
#   197,
#   13],
#  [9,
#   60,
#   36,
#   26,
#   35,
#   13,
#   80,
#   194,
#   22,
#   61,
#   25,
#   195,
#   196,
#   1,
#   5,
#   7,
#   79,
#   2,
#   197,
#   13,
#   198],
#  [9,
#   60,
#   36,
#   26,
#   35,
#   13,
#   80,
#   194,
#   22,
#   61,
#   25,
#   195,
#   196,
#   1,
#   5,
#   7,
#   79,
#   2,
#   197,
#   13,
#   198,
#   32],
#  [9,
#   60,
#   36,
#   26,
#   35,
#   13,
#   80,
#   194,
#   22,
#   61,
#   25,
#   195,
#   196,
#   1,
#   5,
#   7,
#   79,
#   2,
#   197,
#   13,
#   198,
#   32,
#   56],
#  [9,
#   60,
#   36,
#   26,
#   35,
#   13,
#   80,
#   194,
#   22,
#   61,
#   25,
#   195,
#   196,
#   1,
#   5,
#   7,
#   79,
#   2,
#   197,
#   13,
#   198,
#   32,
#   56,
#   199],
#  [9,
#   60,
#   36,
#   26,
#   35,
#   13,
#   80,
#   194,
#   22,
#   61,
#   25,
#   195,
#   196,
#   1,
#   5,
#   7,
#   79,
#   2,
#   197,
#   13,
#   198,
#   32,
#   56,
#   199,
#   13],
#  [9,
#   60,
#   36,
#   26,
#   35,
#   13,
#   80,
#   194,
#   22,
#   61,
#   25,
#   195,
#   196,
#   1,
#   5,
#   7,
#   79,
#   2,
#   197,
#   13,
#   198,
#   32,
#   56,
#   199,
#   13,
#   90],
#  [9,
#   60,
#   36,
#   26,
#   35,
#   13,
#   80,
#   194,
#   22,
#   61,
#   25,
#   195,
#   196,
#   1,
#   5,
#   7,
#   79,
#   2,
#   197,
#   13,
#   198,
#   32,
#   56,
#   199,
#   13,
#   90,
#   10],
#  [9,
#   60,
#   36,
#   26,
#   35,
#   13,
#   80,
#   194,
#   22,
#   61,
#   25,
#   195,
#   196,
#   1,
#   5,
#   7,
#   79,
#   2,
#   197,
#   13,
#   198,
#   32,
#   56,
#   199,
#   13,
#   90,
#   10,
#   200],
#  [9,
#   60,
#   36,
#   26,
#   35,
#   13,
#   80,
#   194,
#   22,
#   61,
#   25,
#   195,
#   196,
#   1,
#   5,
#   7,
#   79,
#   2,
#   197,
#   13,
#   198,
#   32,
#   56,
#   199,
#   13,
#   90,
#   10,
#   200,
#   1],
#  [9,
#   60,
#   36,
#   26,
#   35,
#   13,
#   80,
#   194,
#   22,
#   61,
#   25,
#   195,
#   196,
#   1,
#   5,
#   7,
#   79,
#   2,
#   197,
#   13,
#   198,
#   32,
#   56,
#   199,
#   13,
#   90,
#   10,
#   200,
#   1,
#   78],
#  [9,
#   60,
#   36,
#   26,
#   35,
#   13,
#   80,
#   194,
#   22,
#   61,
#   25,
#   195,
#   196,
#   1,
#   5,
#   7,
#   79,
#   2,
#   197,
#   13,
#   198,
#   32,
#   56,
#   199,
#   13,
#   90,
#   10,
#   200,
#   1,
#   78,
#   6],
#  [9,
#   60,
#   36,
#   26,
#   35,
#   13,
#   80,
#   194,
#   22,
#   61,
#   25,
#   195,
#   196,
#   1,
#   5,
#   7,
#   79,
#   2,
#   197,
#   13,
#   198,
#   32,
#   56,
#   199,
#   13,
#   90,
#   10,
#   200,
#   1,
#   78,
#   6,
#   201],
#  [9,
#   60,
#   36,
#   26,
#   35,
#   13,
#   80,
#   194,
#   22,
#   61,
#   25,
#   195,
#   196,
#   1,
#   5,
#   7,
#   79,
#   2,
#   197,
#   13,
#   198,
#   32,
#   56,
#   199,
#   13,
#   90,
#   10,
#   200,
#   1,
#   78,
#   6,
#   201,
#   34],
#  [8, 202],
#  [8, 202, 15],
#  [8, 202, 15, 4],
#  [8, 202, 15, 4, 91],
#  [8, 202, 15, 4, 91, 17],
#  [8, 202, 15, 4, 91, 17, 5],
#  [8, 202, 15, 4, 91, 17, 5, 11],
#  [9, 2],
#  [9, 2, 91],
#  [9, 2, 91, 4],
#  [9, 2, 91, 4, 2],
#  [9, 2, 91, 4, 2, 203],
#  [9, 2, 91, 4, 2, 203, 204],
#  [9, 2, 91, 4, 2, 203, 204, 2],
#  [9, 2, 91, 4, 2, 203, 204, 2, 205],
#  [9, 2, 91, 4, 2, 203, 204, 2, 205, 6],
#  [9, 2, 91, 4, 2, 203, 204, 2, 205, 6, 35],
#  [9, 2, 91, 4, 2, 203, 204, 2, 205, 6, 35, 18],
#  [9, 2, 91, 4, 2, 203, 204, 2, 205, 6, 35, 18, 206],
#  [9, 2, 91, 4, 2, 203, 204, 2, 205, 6, 35, 18, 206, 13],
#  [9, 2, 91, 4, 2, 203, 204, 2, 205, 6, 35, 18, 206, 13, 207],
#  [9, 2, 91, 4, 2, 203, 204, 2, 205, 6, 35, 18, 206, 13, 207, 208],
#  [9, 2, 91, 4, 2, 203, 204, 2, 205, 6, 35, 18, 206, 13, 207, 208, 90],
#  [9, 2, 91, 4, 2, 203, 204, 2, 205, 6, 35, 18, 206, 13, 207, 208, 90, 10],
#  [9, 2, 91, 4, 2, 203, 204, 2, 205, 6, 35, 18, 206, 13, 207, 208, 90, 10, 4],
#  [9,
#   2,
#   91,
#   4,
#   2,
#   203,
#   204,
#   2,
#   205,
#   6,
#   35,
#   18,
#   206,
#   13,
#   207,
#   208,
#   90,
#   10,
#   4,
#   37],
#  [9,
#   2,
#   91,
#   4,
#   2,
#   203,
#   204,
#   2,
#   205,
#   6,
#   35,
#   18,
#   206,
#   13,
#   207,
#   208,
#   90,
#   10,
#   4,
#   37,
#   23],
#  [9,
#   2,
#   91,
#   4,
#   2,
#   203,
#   204,
#   2,
#   205,
#   6,
#   35,
#   18,
#   206,
#   13,
#   207,
#   208,
#   90,
#   10,
#   4,
#   37,
#   23,
#   2],
#  [9,
#   2,
#   91,
#   4,
#   2,
#   203,
#   204,
#   2,
#   205,
#   6,
#   35,
#   18,
#   206,
#   13,
#   207,
#   208,
#   90,
#   10,
#   4,
#   37,
#   23,
#   2,
#   62],
#  [9,
#   2,
#   91,
#   4,
#   2,
#   203,
#   204,
#   2,
#   205,
#   6,
#   35,
#   18,
#   206,
#   13,
#   207,
#   208,
#   90,
#   10,
#   4,
#   37,
#   23,
#   2,
#   62,
#   209],
#  [9,
#   2,
#   91,
#   4,
#   2,
#   203,
#   204,
#   2,
#   205,
#   6,
#   35,
#   18,
#   206,
#   13,
#   207,
#   208,
#   90,
#   10,
#   4,
#   37,
#   23,
#   2,
#   62,
#   209,
#   22],
#  [9,
#   2,
#   91,
#   4,
#   2,
#   203,
#   204,
#   2,
#   205,
#   6,
#   35,
#   18,
#   206,
#   13,
#   207,
#   208,
#   90,
#   10,
#   4,
#   37,
#   23,
#   2,
#   62,
#   209,
#   22,
#   92],
#  [9,
#   2,
#   91,
#   4,
#   2,
#   203,
#   204,
#   2,
#   205,
#   6,
#   35,
#   18,
#   206,
#   13,
#   207,
#   208,
#   90,
#   10,
#   4,
#   37,
#   23,
#   2,
#   62,
#   209,
#   22,
#   92,
#   10],
#  [9,
#   2,
#   91,
#   4,
#   2,
#   203,
#   204,
#   2,
#   205,
#   6,
#   35,
#   18,
#   206,
#   13,
#   207,
#   208,
#   90,
#   10,
#   4,
#   37,
#   23,
#   2,
#   62,
#   209,
#   22,
#   92,
#   10,
#   210],
#  [9,
#   2,
#   91,
#   4,
#   2,
#   203,
#   204,
#   2,
#   205,
#   6,
#   35,
#   18,
#   206,
#   13,
#   207,
#   208,
#   90,
#   10,
#   4,
#   37,
#   23,
#   2,
#   62,
#   209,
#   22,
#   92,
#   10,
#   210,
#   211],
#  [9,
#   2,
#   91,
#   4,
#   2,
#   203,
#   204,
#   2,
#   205,
#   6,
#   35,
#   18,
#   206,
#   13,
#   207,
#   208,
#   90,
#   10,
#   4,
#   37,
#   23,
#   2,
#   62,
#   209,
#   22,
#   92,
#   10,
#   210,
#   211,
#   17],
#  [9,
#   2,
#   91,
#   4,
#   2,
#   203,
#   204,
#   2,
#   205,
#   6,
#   35,
#   18,
#   206,
#   13,
#   207,
#   208,
#   90,
#   10,
#   4,
#   37,
#   23,
#   2,
#   62,
#   209,
#   22,
#   92,
#   10,
#   210,
#   211,
#   17,
#   2],
#  [9,
#   2,
#   91,
#   4,
#   2,
#   203,
#   204,
#   2,
#   205,
#   6,
#   35,
#   18,
#   206,
#   13,
#   207,
#   208,
#   90,
#   10,
#   4,
#   37,
#   23,
#   2,
#   62,
#   209,
#   22,
#   92,
#   10,
#   210,
#   211,
#   17,
#   2,
#   212],
#  [8, 213],
#  [8, 213, 214],
#  [8, 213, 214, 1],
#  [8, 213, 214, 1, 10],
#  [8, 213, 214, 1, 10, 93],
#  [8, 213, 214, 1, 10, 93, 17],
#  [8, 213, 214, 1, 10, 93, 17, 12],
#  [8, 213, 214, 1, 10, 93, 17, 12, 5],
#  [8, 213, 214, 1, 10, 93, 17, 12, 5, 7],
#  [9, 1],
#  [9, 1, 10],
#  [9, 1, 10, 93],
#  [9, 1, 10, 93, 215],
#  [216, 1],
#  [216, 1, 10],
#  [216, 1, 10, 4],
#  [216, 1, 10, 4, 94],
#  [216, 1, 10, 4, 94, 217],
#  [218, 1],
#  [218, 1, 10],
#  [218, 1, 10, 4],
#  [218, 1, 10, 4, 37],
#  [218, 1, 10, 4, 37, 13],
#  [218, 1, 10, 4, 37, 13, 219],
#  [218, 1, 10, 4, 37, 13, 219, 95],
#  [218, 1, 10, 4, 37, 13, 219, 95, 22],
#  [218, 1, 10, 4, 37, 13, 219, 95, 22, 1],
#  [218, 1, 10, 4, 37, 13, 219, 95, 22, 1, 32],
#  [96, 1],
#  [96, 1, 10],
#  [96, 1, 10, 4],
#  [96, 1, 10, 4, 97],
#  [96, 1, 10, 4, 97, 94],
#  [96, 1, 10, 4, 97, 94, 95],
#  [37, 1],
#  [37, 1, 10],
#  [37, 1, 10, 4],
#  [37, 1, 10, 4, 37],
#  [37, 1, 10, 4, 37, 23],
#  [37, 1, 10, 4, 37, 23, 12],
#  [37, 1, 10, 4, 37, 23, 12, 220],
#  [37, 1, 10, 4, 37, 23, 12, 220, 54],
#  [37, 1, 10, 4, 37, 23, 12, 220, 54, 62],
#  [221, 1],
#  [221, 1, 10],
#  [221, 1, 10, 222],
#  [221, 1, 10, 222, 223],
#  [221, 1, 10, 222, 223, 34],
#  [8, 224],
#  [8, 224, 15],
#  [8, 224, 15, 4],
#  [8, 224, 15, 4, 1],
#  [8, 224, 15, 4, 1, 49],
#  [8, 224, 15, 4, 1, 49, 25],
#  [8, 224, 15, 4, 1, 49, 25, 98],
#  [8, 224, 15, 4, 1, 49, 25, 98, 3],
#  [8, 224, 15, 4, 1, 49, 25, 98, 3, 99],
#  [98, 14],
#  [98, 14, 4],
#  [98, 14, 4, 100],
#  [98, 14, 4, 100, 101],
#  [98, 14, 4, 100, 101, 225],
#  [98, 14, 4, 100, 101, 225, 226],
#  [98, 14, 4, 100, 101, 225, 226, 227],
#  [98, 14, 4, 100, 101, 225, 226, 227, 228],
#  [98, 14, 4, 100, 101, 225, 226, 227, 228, 229],
#  [98, 14, 4, 100, 101, 225, 226, 227, 228, 229, 16],
#  [98, 14, 4, 100, 101, 225, 226, 227, 228, 229, 16, 230],
#  [98, 14, 4, 100, 101, 225, 226, 227, 228, 229, 16, 230, 14],
#  [98, 14, 4, 100, 101, 225, 226, 227, 228, 229, 16, 230, 14, 19],
#  [98, 14, 4, 100, 101, 225, 226, 227, 228, 229, 16, 230, 14, 19, 231],
#  [98, 14, 4, 100, 101, 225, 226, 227, 228, 229, 16, 230, 14, 19, 231, 232],
#  [98,
#   14,
#   4,
#   100,
#   101,
#   225,
#   226,
#   227,
#   228,
#   229,
#   16,
#   230,
#   14,
#   19,
#   231,
#   232,
#   233],
#  [98,
#   14,
#   4,
#   100,
#   101,
#   225,
#   226,
#   227,
#   228,
#   229,
#   16,
#   230,
#   14,
#   19,
#   231,
#   232,
#   233,
#   234],
#  [99, 14],
#  [99, 14, 4],
#  [99, 14, 4, 100],
#  [99, 14, 4, 100, 101],
#  [99, 14, 4, 100, 101, 235],
#  [99, 14, 4, 100, 101, 235, 236],
#  [99, 14, 4, 100, 101, 235, 236, 237],
#  [99, 14, 4, 100, 101, 235, 236, 237, 238],
#  [99, 14, 4, 100, 101, 235, 236, 237, 238, 38],
#  [99, 14, 4, 100, 101, 235, 236, 237, 238, 38, 239],
#  [99, 14, 4, 100, 101, 235, 236, 237, 238, 38, 239, 240],
#  [99, 14, 4, 100, 101, 235, 236, 237, 238, 38, 239, 240, 241],
#  [99, 14, 4, 100, 101, 235, 236, 237, 238, 38, 239, 240, 241, 41],
#  [99, 14, 4, 100, 101, 235, 236, 237, 238, 38, 239, 240, 241, 41, 54],
#  [99, 14, 4, 100, 101, 235, 236, 237, 238, 38, 239, 240, 241, 41, 54, 242],
#  [99,
#   14,
#   4,
#   100,
#   101,
#   235,
#   236,
#   237,
#   238,
#   38,
#   239,
#   240,
#   241,
#   41,
#   54,
#   242,
#   243],
#  [99,
#   14,
#   4,
#   100,
#   101,
#   235,
#   236,
#   237,
#   238,
#   38,
#   239,
#   240,
#   241,
#   41,
#   54,
#   242,
#   243,
#   16],
#  [99,
#   14,
#   4,
#   100,
#   101,
#   235,
#   236,
#   237,
#   238,
#   38,
#   239,
#   240,
#   241,
#   41,
#   54,
#   242,
#   243,
#   16,
#   244],
#  [99,
#   14,
#   4,
#   100,
#   101,
#   235,
#   236,
#   237,
#   238,
#   38,
#   239,
#   240,
#   241,
#   41,
#   54,
#   242,
#   243,
#   16,
#   244,
#   20],
#  [99,
#   14,
#   4,
#   100,
#   101,
#   235,
#   236,
#   237,
#   238,
#   38,
#   239,
#   240,
#   241,
#   41,
#   54,
#   242,
#   243,
#   16,
#   244,
#   20,
#   73],
#  [8, 245],
#  [8, 245, 15],
#  [8, 245, 15, 4],
#  [8, 245, 15, 4, 2],
#  [8, 245, 15, 4, 2, 21],
#  [8, 245, 15, 4, 2, 21, 7],
#  [8, 245, 15, 4, 2, 21, 7, 3],
#  [8, 245, 15, 4, 2, 21, 7, 3, 246],
#  [8, 245, 15, 4, 2, 21, 7, 3, 246, 4],
#  [8, 245, 15, 4, 2, 21, 7, 3, 246, 4, 16],
#  [8, 245, 15, 4, 2, 21, 7, 3, 246, 4, 16, 247],
#  [9, 2],
#  [9, 2, 21],
#  [9, 2, 21, 7],
#  [9, 2, 21, 7, 4],
#  [9, 2, 21, 7, 4, 2],
#  [9, 2, 21, 7, 4, 2, 248],
#  [9, 2, 21, 7, 4, 2, 248, 249],
#  [9, 2, 21, 7, 4, 2, 248, 249, 22],
#  [9, 2, 21, 7, 4, 2, 248, 249, 22, 5],
#  [9, 2, 21, 7, 4, 2, 248, 249, 22, 5, 11],
#  [9, 2, 21, 7, 4, 2, 248, 249, 22, 5, 11, 13],
#  [9, 2, 21, 7, 4, 2, 248, 249, 22, 5, 11, 13, 250],
#  [9, 2, 21, 7, 4, 2, 248, 249, 22, 5, 11, 13, 250, 3],
#  [9, 2, 21, 7, 4, 2, 248, 249, 22, 5, 11, 13, 250, 3, 251],
#  [9, 2, 21, 7, 4, 2, 248, 249, 22, 5, 11, 13, 250, 3, 251, 252],
#  [9, 2, 21, 7, 4, 2, 248, 249, 22, 5, 11, 13, 250, 3, 251, 252, 38],
#  [9, 2, 21, 7, 4, 2, 248, 249, 22, 5, 11, 13, 250, 3, 251, 252, 38, 43],
#  [9, 2, 21, 7, 4, 2, 248, 249, 22, 5, 11, 13, 250, 3, 251, 252, 38, 43, 44],
#  [9,
#   2,
#   21,
#   7,
#   4,
#   2,
#   248,
#   249,
#   22,
#   5,
#   11,
#   13,
#   250,
#   3,
#   251,
#   252,
#   38,
#   43,
#   44,
#   16],
#  [9,
#   2,
#   21,
#   7,
#   4,
#   2,
#   248,
#   249,
#   22,
#   5,
#   11,
#   13,
#   250,
#   3,
#   251,
#   252,
#   38,
#   43,
#   44,
#   16,
#   67],
#  [9,
#   2,
#   21,
#   7,
#   4,
#   2,
#   248,
#   249,
#   22,
#   5,
#   11,
#   13,
#   250,
#   3,
#   251,
#   252,
#   38,
#   43,
#   44,
#   16,
#   67,
#   253],
#  [9,
#   2,
#   21,
#   7,
#   4,
#   2,
#   248,
#   249,
#   22,
#   5,
#   11,
#   13,
#   250,
#   3,
#   251,
#   252,
#   38,
#   43,
#   44,
#   16,
#   67,
#   253,
#   23],
#  [9,
#   2,
#   21,
#   7,
#   4,
#   2,
#   248,
#   249,
#   22,
#   5,
#   11,
#   13,
#   250,
#   3,
#   251,
#   252,
#   38,
#   43,
#   44,
#   16,
#   67,
#   253,
#   23,
#   48],
#  [9,
#   2,
#   21,
#   7,
#   4,
#   2,
#   248,
#   249,
#   22,
#   5,
#   11,
#   13,
#   250,
#   3,
#   251,
#   252,
#   38,
#   43,
#   44,
#   16,
#   67,
#   253,
#   23,
#   48,
#   46],
#  [9,
#   2,
#   21,
#   7,
#   4,
#   2,
#   248,
#   249,
#   22,
#   5,
#   11,
#   13,
#   250,
#   3,
#   251,
#   252,
#   38,
#   43,
#   44,
#   16,
#   67,
#   253,
#   23,
#   48,
#   46,
#   43],
#  [9,
#   2,
#   21,
#   7,
#   4,
#   2,
#   248,
#   249,
#   22,
#   5,
#   11,
#   13,
#   250,
#   3,
#   251,
#   252,
#   38,
#   43,
#   44,
#   16,
#   67,
#   253,
#   23,
#   48,
#   46,
#   43,
#   254],
#  [9,
#   2,
#   21,
#   7,
#   4,
#   2,
#   248,
#   249,
#   22,
#   5,
#   11,
#   13,
#   250,
#   3,
#   251,
#   252,
#   38,
#   43,
#   44,
#   16,
#   67,
#   253,
#   23,
#   48,
#   46,
#   43,
#   254,
#   3],
#  [9,
#   2,
#   21,
#   7,
#   4,
#   2,
#   248,
#   249,
#   22,
#   5,
#   11,
#   13,
#   250,
#   3,
#   251,
#   252,
#   38,
#   43,
#   44,
#   16,
#   67,
#   253,
#   23,
#   48,
#   46,
#   43,
#   254,
#   3,
#   19],
#  [9,
#   2,
#   21,
#   7,
#   4,
#   2,
#   248,
#   249,
#   22,
#   5,
#   11,
#   13,
#   250,
#   3,
#   251,
#   252,
#   38,
#   43,
#   44,
#   16,
#   67,
#   253,
#   23,
#   48,
#   46,
#   43,
#   254,
#   3,
#   19,
#   255],
#  [9,
#   2,
#   21,
#   7,
#   4,
#   2,
#   248,
#   249,
#   22,
#   5,
#   11,
#   13,
#   250,
#   3,
#   251,
#   252,
#   38,
#   43,
#   44,
#   16,
#   67,
#   253,
#   23,
#   48,
#   46,
#   43,
#   254,
#   3,
#   19,
#   255,
#   21],
#  [9,
#   2,
#   21,
#   7,
#   4,
#   2,
#   248,
#   249,
#   22,
#   5,
#   11,
#   13,
#   250,
#   3,
#   251,
#   252,
#   38,
#   43,
#   44,
#   16,
#   67,
#   253,
#   23,
#   48,
#   46,
#   43,
#   254,
#   3,
#   19,
#   255,
#   21,
#   11],
#  [9,
#   2,
#   21,
#   7,
#   4,
#   2,
#   248,
#   249,
#   22,
#   5,
#   11,
#   13,
#   250,
#   3,
#   251,
#   252,
#   38,
#   43,
#   44,
#   16,
#   67,
#   253,
#   23,
#   48,
#   46,
#   43,
#   254,
#   3,
#   19,
#   255,
#   21,
#   11,
#   31],
#  [9,
#   2,
#   21,
#   7,
#   4,
#   2,
#   248,
#   249,
#   22,
#   5,
#   11,
#   13,
#   250,
#   3,
#   251,
#   252,
#   38,
#   43,
#   44,
#   16,
#   67,
#   253,
#   23,
#   48,
#   46,
#   43,
#   254,
#   3,
#   19,
#   255,
#   21,
#   11,
#   31,
#   256],
#  [9,
#   2,
#   21,
#   7,
#   4,
#   2,
#   248,
#   249,
#   22,
#   5,
#   11,
#   13,
#   250,
#   3,
#   251,
#   252,
#   38,
#   43,
#   44,
#   16,
#   67,
#   253,
#   23,
#   48,
#   46,
#   43,
#   254,
#   3,
#   19,
#   255,
#   21,
#   11,
#   31,
#   256,
#   257],
#  [9,
#   2,
#   21,
#   7,
#   4,
#   2,
#   248,
#   249,
#   22,
#   5,
#   11,
#   13,
#   250,
#   3,
#   251,
#   252,
#   38,
#   43,
#   44,
#   16,
#   67,
#   253,
#   23,
#   48,
#   46,
#   43,
#   254,
#   3,
#   19,
#   255,
#   21,
#   11,
#   31,
#   256,
#   257,
#   258],
#  [9,
#   2,
#   21,
#   7,
#   4,
#   2,
#   248,
#   249,
#   22,
#   5,
#   11,
#   13,
#   250,
#   3,
#   251,
#   252,
#   38,
#   43,
#   44,
#   16,
#   67,
#   253,
#   23,
#   48,
#   46,
#   43,
#   254,
#   3,
#   19,
#   255,
#   21,
#   11,
#   31,
#   256,
#   257,
#   258,
#   259],
#  [8, 260],
#  [8, 260, 15],
#  [8, 260, 15, 18],
#  [8, 260, 15, 18, 7],
#  [8, 260, 15, 18, 7, 102],
#  [8, 260, 15, 18, 7, 102, 17],
#  [8, 260, 15, 18, 7, 102, 17, 12],
#  [8, 260, 15, 18, 7, 102, 17, 12, 5],
#  [8, 260, 15, 18, 7, 102, 17, 12, 5, 7],
#  [9, 7],
#  [9, 7, 102],
#  [9, 7, 102, 18],
#  [9, 7, 102, 18, 261],
#  [9, 7, 102, 18, 261, 262],
#  [9, 7, 102, 18, 261, 262, 24],
#  [9, 7, 102, 18, 261, 262, 24, 263],
#  [9, 7, 102, 18, 261, 262, 24, 263, 20],
#  [9, 7, 102, 18, 261, 262, 24, 263, 20, 30],
#  [9, 7, 102, 18, 261, 262, 24, 263, 20, 30, 13],
#  [9, 7, 102, 18, 261, 262, 24, 263, 20, 30, 13, 264],
#  [9, 7, 102, 18, 261, 262, 24, 263, 20, 30, 13, 264, 265],
#  [9, 7, 102, 18, 261, 262, 24, 263, 20, 30, 13, 264, 265, 266],
#  [9, 7, 102, 18, 261, 262, 24, 263, 20, 30, 13, 264, 265, 266, 1],
#  [9, 7, 102, 18, 261, 262, 24, 263, 20, 30, 13, 264, 265, 266, 1, 55],
#  [9, 7, 102, 18, 261, 262, 24, 263, 20, 30, 13, 264, 265, 266, 1, 55, 103],
#  [9, 7, 102, 18, 261, 262, 24, 263, 20, 30, 13, 264, 265, 266, 1, 55, 103, 31],
#  [9,
#   7,
#   102,
#   18,
#   261,
#   262,
#   24,
#   263,
#   20,
#   30,
#   13,
#   264,
#   265,
#   266,
#   1,
#   55,
#   103,
#   31,
#   21],
#  [9,
#   7,
#   102,
#   18,
#   261,
#   262,
#   24,
#   263,
#   20,
#   30,
#   13,
#   264,
#   265,
#   266,
#   1,
#   55,
#   103,
#   31,
#   21,
#   72],
#  [9,
#   7,
#   102,
#   18,
#   261,
#   262,
#   24,
#   263,
#   20,
#   30,
#   13,
#   264,
#   265,
#   266,
#   1,
#   55,
#   103,
#   31,
#   21,
#   72,
#   10],
#  [9,
#   7,
#   102,
#   18,
#   261,
#   262,
#   24,
#   263,
#   20,
#   30,
#   13,
#   264,
#   265,
#   266,
#   1,
#   55,
#   103,
#   31,
#   21,
#   72,
#   10,
#   47],
#  [9,
#   7,
#   102,
#   18,
#   261,
#   262,
#   24,
#   263,
#   20,
#   30,
#   13,
#   264,
#   265,
#   266,
#   1,
#   55,
#   103,
#   31,
#   21,
#   72,
#   10,
#   47,
#   3],
#  [9,
#   7,
#   102,
#   18,
#   261,
#   262,
#   24,
#   263,
#   20,
#   30,
#   13,
#   264,
#   265,
#   266,
#   1,
#   55,
#   103,
#   31,
#   21,
#   72,
#   10,
#   47,
#   3,
#   82],
#  [8, 267],
#  [8, 267, 52],
#  [8, 267, 52, 1],
#  [8, 267, 52, 1, 104],
#  [8, 267, 52, 1, 104, 6],
#  [8, 267, 52, 1, 104, 6, 105],
#  [8, 267, 52, 1, 104, 6, 105, 61],
#  [9, 105],
#  [9, 105, 61],
#  [9, 105, 61, 4],
#  [9, 105, 61, 4, 1],
#  [9, 105, 61, 4, 1, 10],
#  [9, 105, 61, 4, 1, 10, 6],
#  [9, 105, 61, 4, 1, 10, 6, 268],
#  [9, 105, 61, 4, 1, 10, 6, 268, 1],
#  [9, 105, 61, 4, 1, 10, 6, 268, 1, 106],
#  [9, 105, 61, 4, 1, 10, 6, 268, 1, 106, 6],
#  [9, 105, 61, 4, 1, 10, 6, 268, 1, 106, 6, 2],
#  [9, 105, 61, 4, 1, 10, 6, 268, 1, 106, 6, 2, 97],
#  [9, 105, 61, 4, 1, 10, 6, 268, 1, 106, 6, 2, 97, 96],
#  [9, 105, 61, 4, 1, 10, 6, 268, 1, 106, 6, 2, 97, 96, 10],
#  [9, 105, 61, 4, 1, 10, 6, 268, 1, 106, 6, 2, 97, 96, 10, 3],
#  [9, 105, 61, 4, 1, 10, 6, 268, 1, 106, 6, 2, 97, 96, 10, 3, 269],
#  [9, 105, 61, 4, 1, 10, 6, 268, 1, 106, 6, 2, 97, 96, 10, 3, 269, 1],
#  [9, 105, 61, 4, 1, 10, 6, 268, 1, 106, 6, 2, 97, 96, 10, 3, 269, 1, 106],
#  [9, 105, 61, 4, 1, 10, 6, 268, 1, 106, 6, 2, 97, 96, 10, 3, 269, 1, 106, 6],
#  [9,
#   105,
#   61,
#   4,
#   1,
#   10,
#   6,
#   268,
#   1,
#   106,
#   6,
#   2,
#   97,
#   96,
#   10,
#   3,
#   269,
#   1,
#   106,
#   6,
#   92],
#  [9,
#   105,
#   61,
#   4,
#   1,
#   10,
#   6,
#   268,
#   1,
#   106,
#   6,
#   2,
#   97,
#   96,
#   10,
#   3,
#   269,
#   1,
#   106,
#   6,
#   92,
#   10],
#  [9,
#   105,
#   61,
#   4,
#   1,
#   10,
#   6,
#   268,
#   1,
#   106,
#   6,
#   2,
#   97,
#   96,
#   10,
#   3,
#   269,
#   1,
#   106,
#   6,
#   92,
#   10,
#   16],
#  [9,
#   105,
#   61,
#   4,
#   1,
#   10,
#   6,
#   268,
#   1,
#   106,
#   6,
#   2,
#   97,
#   96,
#   10,
#   3,
#   269,
#   1,
#   106,
#   6,
#   92,
#   10,
#   16,
#   36],
#  [9,
#   105,
#   61,
#   4,
#   1,
#   10,
#   6,
#   268,
#   1,
#   106,
#   6,
#   2,
#   97,
#   96,
#   10,
#   3,
#   269,
#   1,
#   106,
#   6,
#   92,
#   10,
#   16,
#   36,
#   60],
#  [9,
#   105,
#   61,
#   4,
#   1,
#   10,
#   6,
#   268,
#   1,
#   106,
#   6,
#   2,
#   97,
#   96,
#   10,
#   3,
#   269,
#   1,
#   106,
#   6,
#   92,
#   10,
#   16,
#   36,
#   60,
#   3],
#  [9,
#   105,
#   61,
#   4,
#   1,
#   10,
#   6,
#   268,
#   1,
#   106,
#   6,
#   2,
#   97,
#   96,
#   10,
#   3,
#   269,
#   1,
#   106,
#   6,
#   92,
#   10,
#   16,
#   36,
#   60,
#   3,
#   270],
#  [9,
#   105,
#   61,
#   4,
#   1,
#   10,
#   6,
#   268,
#   1,
#   106,
#   6,
#   2,
#   97,
#   96,
#   10,
#   3,
#   269,
#   1,
#   106,
#   6,
#   92,
#   10,
#   16,
#   36,
#   60,
#   3,
#   270,
#   32],
#  [9,
#   105,
#   61,
#   4,
#   1,
#   10,
#   6,
#   268,
#   1,
#   106,
#   6,
#   2,
#   97,
#   96,
#   10,
#   3,
#   269,
#   1,
#   106,
#   6,
#   92,
#   10,
#   16,
#   36,
#   60,
#   3,
#   270,
#   32,
#   271],
#  [8, 272],
#  [8, 272, 15],
#  [8, 272, 15, 4],
#  [8, 272, 15, 4, 2],
#  [8, 272, 15, 4, 2, 107],
#  [8, 272, 15, 4, 2, 107, 17],
#  [8, 272, 15, 4, 2, 107, 17, 12],
#  [8, 272, 15, 4, 2, 107, 17, 12, 5],
#  [8, 272, 15, 4, 2, 107, 17, 12, 5, 7],
#  [9, 2],
#  [9, 2, 107],
#  [9, 2, 107, 4],
#  [9, 2, 107, 4, 2],
#  [9, 2, 107, 4, 2, 20],
#  [9, 2, 107, 4, 2, 20, 33],
#  [9, 2, 107, 4, 2, 20, 33, 24],
#  [9, 2, 107, 4, 2, 20, 33, 24, 36],
#  [9, 2, 107, 4, 2, 20, 33, 24, 36, 86],
#  [9, 2, 107, 4, 2, 20, 33, 24, 36, 86, 13],
#  [9, 2, 107, 4, 2, 20, 33, 24, 36, 86, 13, 87],
#  [9, 2, 107, 4, 2, 20, 33, 24, 36, 86, 13, 87, 51],
#  [9, 2, 107, 4, 2, 20, 33, 24, 36, 86, 13, 87, 51, 1],
#  [9, 2, 107, 4, 2, 20, 33, 24, 36, 86, 13, 87, 51, 1, 5],
#  [9, 2, 107, 4, 2, 20, 33, 24, 36, 86, 13, 87, 51, 1, 5, 7],
#  [9, 2, 107, 4, 2, 20, 33, 24, 36, 86, 13, 87, 51, 1, 5, 7, 22],
#  [9, 2, 107, 4, 2, 20, 33, 24, 36, 86, 13, 87, 51, 1, 5, 7, 22, 273],
#  [9, 2, 107, 4, 2, 20, 33, 24, 36, 86, 13, 87, 51, 1, 5, 7, 22, 273, 274],
#  [9, 2, 107, 4, 2, 20, 33, 24, 36, 86, 13, 87, 51, 1, 5, 7, 22, 273, 274, 103],
#  [9,
#   2,
#   107,
#   4,
#   2,
#   20,
#   33,
#   24,
#   36,
#   86,
#   13,
#   87,
#   51,
#   1,
#   5,
#   7,
#   22,
#   273,
#   274,
#   103,
#   31],
#  [9,
#   2,
#   107,
#   4,
#   2,
#   20,
#   33,
#   24,
#   36,
#   86,
#   13,
#   87,
#   51,
#   1,
#   5,
#   7,
#   22,
#   273,
#   274,
#   103,
#   31,
#   275],
#  [9,
#   2,
#   107,
#   4,
#   2,
#   20,
#   33,
#   24,
#   36,
#   86,
#   13,
#   87,
#   51,
#   1,
#   5,
#   7,
#   22,
#   273,
#   274,
#   103,
#   31,
#   275,
#   276],
#  [9,
#   2,
#   107,
#   4,
#   2,
#   20,
#   33,
#   24,
#   36,
#   86,
#   13,
#   87,
#   51,
#   1,
#   5,
#   7,
#   22,
#   273,
#   274,
#   103,
#   31,
#   275,
#   276,
#   3],
#  [9,
#   2,
#   107,
#   4,
#   2,
#   20,
#   33,
#   24,
#   36,
#   86,
#   13,
#   87,
#   51,
#   1,
#   5,
#   7,
#   22,
#   273,
#   274,
#   103,
#   31,
#   275,
#   276,
#   3,
#   277],
#  [9,
#   2,
#   107,
#   4,
#   2,
#   20,
#   33,
#   24,
#   36,
#   86,
#   13,
#   87,
#   51,
#   1,
#   5,
#   7,
#   22,
#   273,
#   274,
#   103,
#   31,
#   275,
#   276,
#   3,
#   277,
#   278],
#  [9,
#   2,
#   107,
#   4,
#   2,
#   20,
#   33,
#   24,
#   36,
#   86,
#   13,
#   87,
#   51,
#   1,
#   5,
#   7,
#   22,
#   273,
#   274,
#   103,
#   31,
#   275,
#   276,
#   3,
#   277,
#   278,
#   279],
#  [8, 280],
#  [8, 280, 89],
#  [8, 280, 89, 281],
#  [8, 280, 89, 281, 63],
#  [8, 280, 89, 281, 63, 5],
#  [8, 280, 89, 281, 63, 5, 11],
#  [8, 280, 89, 281, 63, 5, 11, 64],
#  [8, 280, 89, 281, 63, 5, 11, 64, 45],
#  [9, 63],
#  [9, 63, 5],
#  [9, 63, 5, 11],
#  [9, 63, 5, 11, 64],
#  [9, 63, 5, 11, 64, 45],
#  [9, 63, 5, 11, 64, 45, 282],
#  [283, 3],
#  [283, 3, 46],
#  [283, 3, 46, 47],
#  [48, 284],
#  [285, 3],
#  [285, 3, 286],
#  [285, 3, 286, 287],
#  [285, 3, 286, 287, 11],
#  [288, 6],
#  [288, 6, 30],
#  [289, 290],
#  [289, 290, 3],
#  [289, 290, 3, 291],
#  [8, 292],
#  [8, 292, 15],
#  [8, 292, 15, 4],
#  [8, 292, 15, 4, 1],
#  [8, 292, 15, 4, 1, 293],
#  [8, 292, 15, 4, 1, 293, 6],
#  [8, 292, 15, 4, 1, 293, 6, 12],
#  [8, 292, 15, 4, 1, 293, 6, 12, 108],
#  [8, 292, 15, 4, 1, 293, 6, 12, 108, 17],
#  [8, 292, 15, 4, 1, 293, 6, 12, 108, 17, 5],
#  [8, 292, 15, 4, 1, 293, 6, 12, 108, 17, 5, 11],
#  [9, 12],
#  [9, 12, 108],
#  [9, 12, 108, 4],
#  [9, 12, 108, 4, 2],
#  [9, 12, 108, 4, 2, 294],
#  [9, 12, 108, 4, 2, 294, 24],
#  [9, 12, 108, 4, 2, 294, 24, 295],
#  [9, 12, 108, 4, 2, 294, 24, 295, 1],
#  [9, 12, 108, 4, 2, 294, 24, 295, 1, 32],
#  [9, 12, 108, 4, 2, 294, 24, 295, 1, 32, 13],
#  [9, 12, 108, 4, 2, 294, 24, 295, 1, 32, 13, 296],
#  [9, 12, 108, 4, 2, 294, 24, 295, 1, 32, 13, 296, 74],
#  [9, 12, 108, 4, 2, 294, 24, 295, 1, 32, 13, 296, 74, 297],
#  [9, 12, 108, 4, 2, 294, 24, 295, 1, 32, 13, 296, 74, 297, 109],
#  [9, 12, 108, 4, 2, 294, 24, 295, 1, 32, 13, 296, 74, 297, 109, 3],
#  [9, 12, 108, 4, 2, 294, 24, 295, 1, 32, 13, 296, 74, 297, 109, 3, 68],
#  [9, 12, 108, 4, 2, 294, 24, 295, 1, 32, 13, 296, 74, 297, 109, 3, 68, 2],
#  [9, 12, 108, 4, 2, 294, 24, 295, 1, 32, 13, 296, 74, 297, 109, 3, 68, 2, 110],
#  [9,
#   12,
#   108,
#   4,
#   2,
#   294,
#   24,
#   295,
#   1,
#   32,
#   13,
#   296,
#   74,
#   297,
#   109,
#   3,
#   68,
#   2,
#   110,
#   298],
#  [9,
#   12,
#   108,
#   4,
#   2,
#   294,
#   24,
#   295,
#   1,
#   32,
#   13,
#   296,
#   74,
#   297,
#   109,
#   3,
#   68,
#   2,
#   110,
#   298,
#   109],
#  [9,
#   12,
#   108,
#   4,
#   2,
#   294,
#   24,
#   295,
#   1,
#   32,
#   13,
#   296,
#   74,
#   297,
#   109,
#   3,
#   68,
#   2,
#   110,
#   298,
#   109,
#   299],
#  [9,
#   12,
#   108,
#   4,
#   2,
#   294,
#   24,
#   295,
#   1,
#   32,
#   13,
#   296,
#   74,
#   297,
#   109,
#   3,
#   68,
#   2,
#   110,
#   298,
#   109,
#   299,
#   64],
#  [9,
#   12,
#   108,
#   4,
#   2,
#   294,
#   24,
#   295,
#   1,
#   32,
#   13,
#   296,
#   74,
#   297,
#   109,
#   3,
#   68,
#   2,
#   110,
#   298,
#   109,
#   299,
#   64,
#   300],
#  [9,
#   12,
#   108,
#   4,
#   2,
#   294,
#   24,
#   295,
#   1,
#   32,
#   13,
#   296,
#   74,
#   297,
#   109,
#   3,
#   68,
#   2,
#   110,
#   298,
#   109,
#   299,
#   64,
#   300,
#   301],
#  [9,
#   12,
#   108,
#   4,
#   2,
#   294,
#   24,
#   295,
#   1,
#   32,
#   13,
#   296,
#   74,
#   297,
#   109,
#   3,
#   68,
#   2,
#   110,
#   298,
#   109,
#   299,
#   64,
#   300,
#   301,
#   13],
#  [9,
#   12,
#   108,
#   4,
#   2,
#   294,
#   24,
#   295,
#   1,
#   32,
#   13,
#   296,
#   74,
#   297,
#   109,
#   3,
#   68,
#   2,
#   110,
#   298,
#   109,
#   299,
#   64,
#   300,
#   301,
#   13,
#   302],
#  [9,
#   12,
#   108,
#   4,
#   2,
#   294,
#   24,
#   295,
#   1,
#   32,
#   13,
#   296,
#   74,
#   297,
#   109,
#   3,
#   68,
#   2,
#   110,
#   298,
#   109,
#   299,
#   64,
#   300,
#   301,
#   13,
#   302,
#   303],
#  [8, 304],
#  [8, 304, 15],
#  [8, 304, 15, 4],
#  [8, 304, 15, 4, 1],
#  [8, 304, 15, 4, 1, 49],
#  [8, 304, 15, 4, 1, 49, 25],
#  [8, 304, 15, 4, 1, 49, 25, 111],
#  [8, 304, 15, 4, 1, 49, 25, 111, 3],
#  [8, 304, 15, 4, 1, 49, 25, 111, 3, 112],
#  [8, 304, 15, 4, 1, 49, 25, 111, 3, 112, 65],
#  [111, 65],
#  [111, 65, 305],
#  [111, 65, 305, 306],
#  [111, 65, 305, 306, 113],
#  [111, 65, 305, 306, 113, 76],
#  [111, 65, 305, 306, 113, 76, 1],
#  [111, 65, 305, 306, 113, 76, 1, 77],
#  [111, 65, 305, 306, 113, 76, 1, 77, 14],
#  [111, 65, 305, 306, 113, 76, 1, 77, 14, 3],
#  [111, 65, 305, 306, 113, 76, 1, 77, 14, 3, 114],
#  [111, 65, 305, 306, 113, 76, 1, 77, 14, 3, 114, 307],
#  [112, 65],
#  [112, 65, 308],
#  [112, 65, 308, 113],
#  [112, 65, 308, 113, 18],
#  [112, 65, 308, 113, 18, 309],
#  [112, 65, 308, 113, 18, 309, 310],
#  [112, 65, 308, 113, 18, 309, 310, 114],
#  [112, 65, 308, 113, 18, 309, 310, 114, 51],
#  [112, 65, 308, 113, 18, 309, 310, 114, 51, 311],
#  [112, 65, 308, 113, 18, 309, 310, 114, 51, 311, 312],
#  [112, 65, 308, 113, 18, 309, 310, 114, 51, 311, 312, 313],
#  [112, 65, 308, 113, 18, 309, 310, 114, 51, 311, 312, 313, 314],
#  [112, 65, 308, 113, 18, 309, 310, 114, 51, 311, 312, 313, 314, 27],
#  [112, 65, 308, 113, 18, 309, 310, 114, 51, 311, 312, 313, 314, 27, 1],
#  [112, 65, 308, 113, 18, 309, 310, 114, 51, 311, 312, 313, 314, 27, 1, 315],
#  [8, 316],
#  [8, 316, 52],
#  [8, 316, 52, 1],
#  [8, 316, 52, 1, 104],
#  [8, 316, 52, 1, 104, 6],
#  [8, 316, 52, 1, 104, 6, 2],
#  [8, 316, 52, 1, 104, 6, 2, 115],
#  [9, 2],
#  [9, 2, 115],
#  [9, 2, 115, 4],
#  [9, 2, 115, 4, 39],
#  [9, 2, 115, 4, 39, 24],
#  [9, 2, 115, 4, 39, 24, 317],
#  [9, 2, 115, 4, 39, 24, 317, 3],
#  [9, 2, 115, 4, 39, 24, 317, 3, 40],
#  [9, 2, 115, 4, 39, 24, 317, 3, 40, 53],
#  [9, 2, 115, 4, 39, 24, 317, 3, 40, 53, 318],
#  [9, 2, 115, 4, 39, 24, 317, 3, 40, 53, 318, 22],
#  [9, 2, 115, 4, 39, 24, 317, 3, 40, 53, 318, 22, 319],
#  [9, 2, 115, 4, 39, 24, 317, 3, 40, 53, 318, 22, 319, 28],
#  [9, 2, 115, 4, 39, 24, 317, 3, 40, 53, 318, 22, 319, 28, 29],
#  [9, 2, 115, 4, 39, 24, 317, 3, 40, 53, 318, 22, 319, 28, 29, 84],
#  [9, 2, 115, 4, 39, 24, 317, 3, 40, 53, 318, 22, 319, 28, 29, 84, 31],
#  [116, 66],
#  [116, 66, 117],
#  [116, 66, 117, 320],
#  [116, 66, 117, 320, 38],
#  [116, 66, 117, 320, 38, 28],
#  [116, 66, 117, 320, 38, 28, 58],
#  [116, 66, 117, 320, 38, 28, 58, 59],
#  [116, 66, 117, 320, 38, 28, 58, 59, 321],
#  [116, 66, 117, 320, 38, 28, 58, 59, 321, 322],
#  [116, 70],
#  [116, 70, 117],
#  [116, 70, 117, 38],
#  [116, 70, 117, 38, 2],
#  [116, 70, 117, 38, 2, 323],
#  [116, 70, 117, 38, 2, 323, 5],
#  [116, 70, 117, 38, 2, 323, 5, 7],
#  [116, 70, 117, 38, 2, 323, 5, 7, 58],
#  [116, 70, 117, 38, 2, 323, 5, 7, 58, 59],
#  [116, 70, 117, 38, 2, 323, 5, 7, 58, 59, 324],
#  [8, 325],
#  [8, 325, 15],
#  [8, 325, 15, 18],
#  [8, 325, 15, 18, 326],
#  [8, 325, 15, 18, 326, 118],
#  [8, 325, 15, 18, 326, 118, 327],
#  [8, 325, 15, 18, 326, 118, 327, 6],
#  [8, 325, 15, 18, 326, 118, 327, 6, 63],
#  [8, 325, 15, 18, 326, 118, 327, 6, 63, 5],
#  [8, 325, 15, 18, 326, 118, 327, 6, 63, 5, 11],
#  [328, 23],
#  [328, 23, 329],
#  [328, 23, 329, 330],
#  [118, 14],
#  [118, 14, 19],
#  [332, 333],
#  [110, 83],
#  [110, 83, 21],
#  [110, 83, 21, 11],
#  [8, 334],
#  [8, 334, 15],
#  [8, 334, 15, 18],
#  [8, 334, 15, 18, 57],
#  [8, 334, 15, 18, 57, 5],
#  [8, 334, 15, 18, 57, 5, 11],
#  [9, 57],
#  [9, 57, 5],
#  [9, 57, 5, 11],
#  [9, 57, 5, 11, 335],
#  [9, 57, 5, 11, 335, 26],
#  [9, 57, 5, 11, 335, 26, 336],
#  [9, 57, 5, 11, 335, 26, 336, 11],
#  [9, 57, 5, 11, 335, 26, 336, 11, 13],
#  [9, 57, 5, 11, 335, 26, 336, 11, 13, 337],
#  [9, 57, 5, 11, 335, 26, 336, 11, 13, 337, 2],
#  [9, 57, 5, 11, 335, 26, 336, 11, 13, 337, 2, 338],
#  [9, 57, 5, 11, 335, 26, 336, 11, 13, 337, 2, 338, 339],
#  [9, 57, 5, 11, 335, 26, 336, 11, 13, 337, 2, 338, 339, 340],
#  [9, 57, 5, 11, 335, 26, 336, 11, 13, 337, 2, 338, 339, 340, 341],
#  [9, 57, 5, 11, 335, 26, 336, 11, 13, 337, 2, 338, 339, 340, 341, 62],
#  [9, 57, 5, 11, 335, 26, 336, 11, 13, 337, 2, 338, 339, 340, 341, 62, 85],
#  [9, 57, 5, 11, 335, 26, 336, 11, 13, 337, 2, 338, 339, 340, 341, 62, 85, 342],
#  [9,
#   57,
#   5,
#   11,
#   335,
#   26,
#   336,
#   11,
#   13,
#   337,
#   2,
#   338,
#   339,
#   340,
#   341,
#   62,
#   85,
#   342,
#   343],
#  [9,
#   57,
#   5,
#   11,
#   335,
#   26,
#   336,
#   11,
#   13,
#   337,
#   2,
#   338,
#   339,
#   340,
#   341,
#   62,
#   85,
#   342,
#   343,
#   3],
#  [9,
#   57,
#   5,
#   11,
#   335,
#   26,
#   336,
#   11,
#   13,
#   337,
#   2,
#   338,
#   339,
#   340,
#   341,
#   62,
#   85,
#   342,
#   343,
#   3,
#   344],
#  [9,
#   57,
#   5,
#   11,
#   335,
#   26,
#   336,
#   11,
#   13,
#   337,
#   2,
#   338,
#   339,
#   340,
#   341,
#   62,
#   85,
#   342,
#   343,
#   3,
#   344,
#   345],
#  [9,
#   57,
#   5,
#   11,
#   335,
#   26,
#   336,
#   11,
#   13,
#   337,
#   2,
#   338,
#   339,
#   340,
#   341,
#   62,
#   85,
#   342,
#   343,
#   3,
#   344,
#   345,
#   346],
#  [9,
#   57,
#   5,
#   11,
#   335,
#   26,
#   336,
#   11,
#   13,
#   337,
#   2,
#   338,
#   339,
#   340,
#   341,
#   62,
#   85,
#   342,
#   343,
#   3,
#   344,
#   345,
#   346,
#   347]]

# %%
max_length_sequence = max([len(x) for x in input_sequences])
max_length_sequence
# Out:
# 48

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_input_sequences = pad_sequences(input_sequences , max_length_sequence  , padding = 'pre')

# %%
padded_input_sequences
# Out:
# array([[  0,   0,   0, ...,   0,   8,  66],
#        [  0,   0,   0, ...,   8,  66,  15],
#        [  0,   0,   0, ...,  66,  15,   4],
#        ...,
#        [  0,   0,   0, ...,   3, 344, 345],
#        [  0,   0,   0, ..., 344, 345, 346],
#        [  0,   0,   0, ..., 345, 346, 347]], dtype=int32)

# %%
X = padded_input_sequences[:,:-1]
y = padded_input_sequences[:,-1]

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y , num_classes = len(tokenizer.word_index) + 1)

# %%
y.shape
# Out:
# (819, 348)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding , LSTM , Dense

# %%
model = Sequential()
model.add(Embedding(len(tokenizer.word_index) + 1, 100, input_length=max_length_sequence-1))
model.add(LSTM(150))
model.add(Dense(len(tokenizer.word_index) + 1, activation='softmax'))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X , y , epochs = 60)
# Out:
# Epoch 1/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 177ms/step - accuracy: 0.0351 - loss: 5.7579
# Epoch 2/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.0284 - loss: 5.2037
# Epoch 3/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - accuracy: 0.0534 - loss: 5.1020
# Epoch 4/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.0452 - loss: 5.0395
# Epoch 5/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - accuracy: 0.0456 - loss: 5.0192
# Epoch 6/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.0891 - loss: 4.7845
# Epoch 7/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.1239 - loss: 4.7431
# Epoch 8/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - accuracy: 0.1286 - loss: 4.6083
# Epoch 9/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - accuracy: 0.1207 - loss: 4.4394
# Epoch 10/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - accuracy: 0.1649 - loss: 4.2420
# Epoch 11/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.2051 - loss: 4.0082
# Epoch 12/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - accuracy: 0.1980 - loss: 3.8576
# Epoch 13/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - accuracy: 0.2468 - loss: 3.6597
# Epoch 14/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - accuracy: 0.2364 - loss: 3.5834
# Epoch 15/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 0.2738 - loss: 3.3707
# Epoch 16/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 131ms/step - accuracy: 0.2904 - loss: 3.1390
# Epoch 17/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - accuracy: 0.3116 - loss: 2.9958
# Epoch 18/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.3416 - loss: 2.8491
# Epoch 19/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - accuracy: 0.3655 - loss: 2.6897
# Epoch 20/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.4197 - loss: 2.5140
# Epoch 21/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 0.4656 - loss: 2.3889
# Epoch 22/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - accuracy: 0.5109 - loss: 2.2173
# Epoch 23/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - accuracy: 0.5641 - loss: 2.0897
# Epoch 24/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.6043 - loss: 1.9376
# Epoch 25/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - accuracy: 0.6404 - loss: 1.8357
# Epoch 26/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 0.6807 - loss: 1.7406
# Epoch 27/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - accuracy: 0.7068 - loss: 1.6114
# Epoch 28/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.7159 - loss: 1.5807
# Epoch 29/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 133ms/step - accuracy: 0.7557 - loss: 1.4134
# Epoch 30/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - accuracy: 0.7691 - loss: 1.3500
# Epoch 31/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - accuracy: 0.7874 - loss: 1.2838
# Epoch 32/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.8396 - loss: 1.1647
# Epoch 33/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - accuracy: 0.8274 - loss: 1.1384
# Epoch 34/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.8506 - loss: 1.0544
# Epoch 35/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - accuracy: 0.8690 - loss: 0.9900
# Epoch 36/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.8716 - loss: 0.9555
# Epoch 37/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - accuracy: 0.8937 - loss: 0.8882
# Epoch 38/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 133ms/step - accuracy: 0.8888 - loss: 0.8286
# Epoch 39/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - accuracy: 0.9162 - loss: 0.7713
# Epoch 40/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - accuracy: 0.9077 - loss: 0.7309
# Epoch 41/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.9064 - loss: 0.7163
# Epoch 42/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - accuracy: 0.9235 - loss: 0.6624
# Epoch 43/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 131ms/step - accuracy: 0.9213 - loss: 0.6235
# Epoch 44/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - accuracy: 0.9118 - loss: 0.6227
# Epoch 45/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.9088 - loss: 0.6137
# Epoch 46/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - accuracy: 0.9067 - loss: 0.5896
# Epoch 47/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.9285 - loss: 0.5105
# Epoch 48/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - accuracy: 0.9241 - loss: 0.5108
# Epoch 49/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 0.9061 - loss: 0.5259
# Epoch 50/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.9345 - loss: 0.4592
# Epoch 51/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.9380 - loss: 0.4302
# Epoch 52/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.9303 - loss: 0.4243
# Epoch 53/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - accuracy: 0.9228 - loss: 0.4486
# Epoch 54/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - accuracy: 0.9241 - loss: 0.4318
# Epoch 55/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.9321 - loss: 0.3895
# Epoch 56/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.9363 - loss: 0.3722
# Epoch 57/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - accuracy: 0.9227 - loss: 0.3811
# Epoch 58/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.9265 - loss: 0.3818
# Epoch 59/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - accuracy: 0.9442 - loss: 0.3394
# Epoch 60/60
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - accuracy: 0.9530 - loss: 0.3088

# %%
text = "What is an operating system?"

# %%
import numpy as np
for i in range(20):
    token_text = tokenizer.texts_to_sequences([text])[0] #Bcs we need list not nested list

    padded_token_text = pad_sequences([token_text], maxlen=max_length_sequence-1, padding='pre')

    pos_of_maxProbability_word = np.argmax(model.predict(padded_token_text))

    for word , index in tokenizer.word_index.items():
        if index == pos_of_maxProbability_word:
            text = text + " " + word
            print(text)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# What is an operating system? os
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# What is an operating system? os is
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# What is an operating system? os is a
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# What is an operating system? os is a software
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# What is an operating system? os is a software that
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# What is an operating system? os is a software that acts
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# What is an operating system? os is a software that acts as
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# What is an operating system? os is a software that acts as an
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# What is an operating system? os is a software that acts as an interface
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# What is an operating system? os is a software that acts as an interface between
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# What is an operating system? os is a software that acts as an interface between hardware
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# What is an operating system? os is a software that acts as an interface between hardware and
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# What is an operating system? os is a software that acts as an interface between hardware and the
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# What is an operating system? os is a software that acts as an interface between hardware and the user
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# What is an operating system? os is a software that acts as an interface between hardware and the user it
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# What is an operating system? os is a software that acts as an interface between hardware and the user it manages
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# What is an operating system? os is a software that acts as an interface between hardware and the user it manages hardware
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# What is an operating system? os is a software that acts as an interface between hardware and the user it manages hardware resources
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# What is an operating system? os is a software that acts as an interface between hardware and the user it manages hardware resources provides
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# What is an operating system? os is a software that acts as an interface between hardware and the user it manages hardware resources provides basic
